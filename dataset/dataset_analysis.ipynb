# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'C:\Users\Krupa P\OneDrive\Desktop\stylemate\dataset\personalized_fashion_dataset_500 (1).csv')

df.head()
# Out:
#   Image_ID Body_Shape  Shoulder_cm  Waist_cm  Hip_cm  Hip_Waist_Ratio  \
# 0  IMG_001  Rectangle           44        27      34             1.26
# 1  IMG_002       Pear           34        26      35             1.35
# 2  IMG_003  Rectangle           37        33      43             1.30
# 3  IMG_004  Hourglass           35        27      40             1.48
# 4  IMG_005      Apple           48        32      35             1.09
#
#   Colour_Palette Garment_Type Garment_Colour      Sleeve    Neckline  \
# 0           Warm       Blouse       Sky Blue  Sleeveless   High Neck
# 1        Neutral      Sweater       Sky Blue  Sleeveless      Square
# 2           Warm       Blouse          Brown         3/4      Collar
# 3           Cool      Sweater         Maroon        Half  Sweetheart
# 4        Neutral      Sweater            Red        Half      Square
#
#      Pattern     Fabric     Occasion Recommendation
# 0  Polka Dot  Polyester       Casual  Pleated Skirt
# ...

# %%
df.shape
# Out:
# (500, 15)

# %%
df.columns
# Out:
# Index(['Image_ID', 'Body_Shape', 'Shoulder_cm', 'Waist_cm', 'Hip_cm',
#        'Hip_Waist_Ratio', 'Colour_Palette', 'Garment_Type', 'Garment_Colour',
#        'Sleeve', 'Neckline', 'Pattern', 'Fabric', 'Occasion',
#        'Recommendation'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Image_ID           0
# Body_Shape         0
# Shoulder_cm        0
# Waist_cm           0
# Hip_cm             0
# Hip_Waist_Ratio    0
# Colour_Palette     0
# Garment_Type       0
# Garment_Colour     0
# Sleeve             0
# Neckline           0
# Pattern            0
# Fabric             0
# Occasion           0
# Recommendation     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Image_ID, Body_Shape, Shoulder_cm, Waist_cm, Hip_cm, Hip_Waist_Ratio, Colour_Palette, Garment_Type, Garment_Colour, Sleeve, Neckline, Pattern, Fabric, Occasion, Recommendation]
# Index: []

# %%
numeric_columns = [
    "Height_cm",
    "Shoulder_cm",
    "Bust_cm",
    "Waist_cm",
    "Hip_cm"
]

for column in numeric_columns:
    df[column] = df[column].fillna(df[column].median())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Image_ID', 'Body_Shape', 'Shoulder_cm', 'Waist_cm', 'Hip_cm', 'Hip_Waist_Ratio', 'Colour_Palette', 'Garment_Type', 'Garment_Colour', 'Sleeve', 'Neckline', 'Pattern', 'Fabric', 'Occasion', 'Recommendation']

# %%
import numpy as np

# %%
np.random.seed(42)

df["Height_cm"] = np.random.normal(
    loc=165,
    scale=8,
    size=len(df)
).round(1)

# %%
df["Height_cm"] = df["Height_cm"].clip(
    lower=145,
    upper=190
)

# %%
import numpy as np

# Generate sample height values
np.random.seed(42)

df["Height_cm"] = np.random.normal(
    loc=165,
    scale=8,
    size=len(df)
).round(1)

# Keep heights within the selected range
df["Height_cm"] = df["Height_cm"].clip(
    lower=145,
    upper=190
)

# Check the result
print(df[["Image_ID", "Height_cm"]].head())
print(df["Height_cm"].describe())
# Out:
#   Image_ID  Height_cm
# 0  IMG_001      169.0
# 1  IMG_002      163.9
# 2  IMG_003      170.2
# 3  IMG_004      177.2
# 4  IMG_005      163.1
# count    500.000000
# mean     165.056600
# std        7.767899
# min      145.000000
# 25%      159.400000
# 50%      165.100000
# 75%      170.125000
# max      190.000000
# Name: Height_cm, dtype: float64

# %%
np.random.seed(42)

new_heights = np.random.normal(
    loc=165,
    scale=8,
    size=len(df)
).round(1)

new_heights = np.clip(new_heights, 145, 190)

df["Height_cm"] = df["Height_cm"].fillna(
    pd.Series(new_heights, index=df.index)
)

# %%
df["Height_cm"]
# Out:
# 0      169.0
# 1      163.9
# 2      170.2
# 3      177.2
# 4      163.1
#        ...
# 495    169.3
# 496    156.7
# 497    163.5
# 498    158.0
# 499    153.9
# Name: Height_cm, Length: 500, dtype: float64

# %%
df.head()
# Out:
#   Image_ID Body_Shape  Shoulder_cm  Waist_cm  Hip_cm  Hip_Waist_Ratio  \
# 0  IMG_001  Rectangle           44        27      34             1.26
# 1  IMG_002       Pear           34        26      35             1.35
# 2  IMG_003  Rectangle           37        33      43             1.30
# 3  IMG_004  Hourglass           35        27      40             1.48
# 4  IMG_005      Apple           48        32      35             1.09
#
#   Colour_Palette Garment_Type Garment_Colour      Sleeve    Neckline  \
# 0           Warm       Blouse       Sky Blue  Sleeveless   High Neck
# 1        Neutral      Sweater       Sky Blue  Sleeveless      Square
# 2           Warm       Blouse          Brown         3/4      Collar
# 3           Cool      Sweater         Maroon        Half  Sweetheart
# 4        Neutral      Sweater            Red        Half      Square
#
#      Pattern     Fabric     Occasion Recommendation  Height_cm
# 0  Polka Dot  Polyester       Casual  Pleated Skirt      169.0
# ...

# %%
df.shape
# Out:
# (500, 16)

# %%
for column in df.columns:
    print(column)
# Out:
# Image_ID
# Body_Shape
# Shoulder_cm
# Waist_cm
# Hip_cm
# Hip_Waist_Ratio
# Colour_Palette
# Garment_Type
# Garment_Colour
# Sleeve
# Neckline
# Pattern
# Fabric
# Occasion
# Recommendation
# Height_cm

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Image_ID         500 non-null    str
#  1   Body_Shape       500 non-null    str
#  2   Shoulder_cm      500 non-null    int64
#  3   Waist_cm         500 non-null    int64
#  4   Hip_cm           500 non-null    int64
#  5   Hip_Waist_Ratio  500 non-null    float64
#  6   Colour_Palette   500 non-null    str
#  7   Garment_Type     500 non-null    str
#  8   Garment_Colour   500 non-null    str
#  9   Sleeve           500 non-null    str
#  10  Neckline         500 non-null    str
#  11  Pattern          500 non-null    str
#  12  Fabric           500 non-null    str
#  13  Occasion         500 non-null    str
#  14  Recommendation   500 non-null    str
#  15  Height_cm        500 non-null    float64
# dtypes: float64(2), int64(3), str(11)
# memory usage: 98.8 KB

# %%
df.isnull().sum()
# Out:
# Image_ID           0
# Body_Shape         0
# Shoulder_cm        0
# Waist_cm           0
# Hip_cm             0
# Hip_Waist_Ratio    0
# Colour_Palette     0
# Garment_Type       0
# Garment_Colour     0
# Sleeve             0
# Neckline           0
# Pattern            0
# Fabric             0
# Occasion           0
# Recommendation     0
# Height_cm          0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
numeric_columns = [
    "Height_cm",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm"
]

for column in numeric_columns:
    if column in df.columns:
        df[column] = pd.to_numeric(df[column], errors="coerce")
        df[column] = df[column].fillna(df[column].median())

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (500, 16)

# %%
df.columns = df.columns.str.strip()

# %%
text_columns = df.select_dtypes(include="object").columns

for column in text_columns:
    df[column] = df[column].str.strip()
# Out:
# C:\Users\Krupa P\AppData\Local\Temp\ipykernel_12268\2819871510.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   text_columns = df.select_dtypes(include="object").columns

# %%
print(df["Body_Shape"].value_counts())
print(df["Colour_Palette"].value_counts())
# Out:
# Body_Shape
# Inverted Triangle    120
# Rectangle            112
# Pear                  94
# Apple                 93
# Hourglass             81
# Name: count, dtype: int64
# Colour_Palette
# Neutral    177
# Cool       167
# Warm       156
# Name: count, dtype: int64

# %%
for column in df.columns:
    print(column)
# Out:
# Image_ID
# Body_Shape
# Shoulder_cm
# Waist_cm
# Hip_cm
# Hip_Waist_Ratio
# Colour_Palette
# Garment_Type
# Garment_Colour
# Sleeve
# Neckline
# Pattern
# Fabric
# Occasion
# Recommendation
# Height_cm

# %%
df.describe()
# Out:
#        Shoulder_cm    Waist_cm      Hip_cm  Hip_Waist_Ratio   Height_cm
# count   500.000000  500.000000  500.000000       500.000000  500.000000
# mean     41.316000   33.084000   41.054000         1.263360  165.056600
# std       4.346715    4.414058    4.141665         0.213445    7.767899
# min      34.000000   26.000000   34.000000         0.870000  145.000000
# 25%      37.000000   29.000000   37.000000         1.100000  159.400000
# 50%      41.000000   33.000000   41.000000         1.230000  165.100000
# 75%      45.000000   37.000000   45.000000         1.412500  170.125000
# max      48.000000   40.000000   48.000000         1.850000  190.000000

# %%
measurement_columns = [
    "Height_cm",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm"
]

for column in measurement_columns:
    if column in df.columns:
        print(column, (df[column] <= 0).sum())
# Out:
# Height_cm 0
# Shoulder_cm 0
# Waist_cm 0
# Hip_cm 0

# %%
df[df["Height_cm"] <= 0]
# Out:
# Empty DataFrame
# Columns: [Image_ID, Body_Shape, Shoulder_cm, Waist_cm, Hip_cm, Hip_Waist_Ratio, Colour_Palette, Garment_Type, Garment_Colour, Sleeve, Neckline, Pattern, Fabric, Occasion, Recommendation, Height_cm]
# Index: []

# %%
df["Hip_Waist_Ratio_Calculated"] = (
    df["Hip_cm"] / df["Waist_cm"]
)

# %%
df[
    [
        "Hip_Waist_Ratio",
        "Hip_Waist_Ratio_Calculated"
    ]
].head(10)
# Out:
#    Hip_Waist_Ratio  Hip_Waist_Ratio_Calculated
# 0             1.26                    1.259259
# 1             1.35                    1.346154
# 2             1.30                    1.303030
# 3             1.48                    1.481481
# 4             1.09                    1.093750
# 5             1.59                    1.586207
# 6             1.19                    1.193548
# 7             1.19                    1.187500
# 8             1.17                    1.166667
# 9             1.10                    1.100000

# %%
df = df.drop(columns=["Hip_Waist_Ratio_Calculated"])

# %%
print(df.columns.tolist())
# Out:
# ['Image_ID', 'Body_Shape', 'Shoulder_cm', 'Waist_cm', 'Hip_cm', 'Hip_Waist_Ratio', 'Colour_Palette', 'Garment_Type', 'Garment_Colour', 'Sleeve', 'Neckline', 'Pattern', 'Fabric', 'Occasion', 'Recommendation', 'Height_cm']

# %%
print(df["Body_Shape"].unique())
print(df["Colour_Palette"].unique())
# Out:
# <ArrowStringArray>
# ['Rectangle', 'Pear', 'Hourglass', 'Apple', 'Inverted Triangle']
# Length: 5, dtype: str
# <ArrowStringArray>
# ['Warm', 'Neutral', 'Cool']
# Length: 3, dtype: str

# %%
df.to_csv(
    "../dataset/StyleMate_cleaned.csv",
    index=False
)

# %%
print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.

# %%
df.shape
# Out:
# (500, 16)

# %%
df.isnull().sum()
# Out:
# Image_ID           0
# Body_Shape         0
# Shoulder_cm        0
# Waist_cm           0
# Hip_cm             0
# Hip_Waist_Ratio    0
# Colour_Palette     0
# Garment_Type       0
# Garment_Colour     0
# Sleeve             0
# Neckline           0
# Pattern            0
# Fabric             0
# Occasion           0
# Recommendation     0
# Height_cm          0
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of     Image_ID         Body_Shape  Shoulder_cm  Waist_cm  Hip_cm  \
# 0    IMG_001          Rectangle           44        27      34
# 1    IMG_002               Pear           34        26      35
# 2    IMG_003          Rectangle           37        33      43
# 3    IMG_004          Hourglass           35        27      40
# 4    IMG_005              Apple           48        32      35
# ..       ...                ...          ...       ...     ...
# 495  IMG_496               Pear           36        37      44
# 496  IMG_497               Pear           37        29      47
# 497  IMG_498  Inverted Triangle           48        27      44
# 498  IMG_499              Apple           41        40      48
# 499  IMG_500          Hourglass           46        35      36
#
#      Hip_Waist_Ratio Colour_Palette Garment_Type Garment_Colour      Sleeve  \
# 0               1.26           Warm       Blouse       Sky Blue  Sleeveless
# ...

# %%
df.to_csv("../dataset/StyleMate_with_height.csv", index=False)

# %%
df["Calculated_Ratio"] = df["Hip_cm"] / df["Waist_cm"]

df[
    ["Hip_cm", "Waist_cm", "Hip_Waist_Ratio", "Calculated_Ratio"]
].head(10)
# Out:
#    Hip_cm  Waist_cm  Hip_Waist_Ratio  Calculated_Ratio
# 0      34        27             1.26          1.259259
# 1      35        26             1.35          1.346154
# 2      43        33             1.30          1.303030
# 3      40        27             1.48          1.481481
# 4      35        32             1.09          1.093750
# 5      46        29             1.59          1.586207
# 6      37        31             1.19          1.193548
# 7      38        32             1.19          1.187500
# 8      35        30             1.17          1.166667
# 9      44        40             1.10          1.100000

# %%
df["Ratio_Difference"] = abs(
    df["Hip_Waist_Ratio"] - df["Calculated_Ratio"]
)

print(df["Ratio_Difference"].max())
# Out:
# 0.0050000000000000044

# %%
df["Calculated_Ratio"] = df["Calculated_Ratio"].round(2)

# %%
df[
    ["Hip_Waist_Ratio", "Calculated_Ratio"]
].head(10)
# Out:
#    Hip_Waist_Ratio  Calculated_Ratio
# 0             1.26              1.26
# 1             1.35              1.35
# 2             1.30              1.30
# 3             1.48              1.48
# 4             1.09              1.09
# 5             1.59              1.59
# 6             1.19              1.19
# 7             1.19              1.19
# 8             1.17              1.17
# 9             1.10              1.10

# %%
df = df.drop(
    columns=["Calculated_Ratio", "Ratio_Difference"],
    errors="ignore"
)

# %%
df.to_csv(
    "../dataset/StyleMate_cleaned.csv",
    index=False
)

print("Dataset saved successfully.")
# Out:
# Dataset saved successfully.

# %%
df = df.drop(
    columns=["Calculated_Ratio", "Ratio_Difference"],
    errors="ignore"
)

# %%
df.isnull().sum()
# Out:
# Image_ID           0
# Body_Shape         0
# Shoulder_cm        0
# Waist_cm           0
# Hip_cm             0
# Hip_Waist_Ratio    0
# Colour_Palette     0
# Garment_Type       0
# Garment_Colour     0
# Sleeve             0
# Neckline           0
# Pattern            0
# Fabric             0
# Occasion           0
# Recommendation     0
# Height_cm          0
# dtype: int64

# %%
print("Total missing values:", df.isnull().sum().sum())
# Out:
# Total missing values: 0

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Image_ID         500 non-null    str
#  1   Body_Shape       500 non-null    str
#  2   Shoulder_cm      500 non-null    int64
#  3   Waist_cm         500 non-null    int64
#  4   Hip_cm           500 non-null    int64
#  5   Hip_Waist_Ratio  500 non-null    float64
#  6   Colour_Palette   500 non-null    str
#  7   Garment_Type     500 non-null    str
#  8   Garment_Colour   500 non-null    str
#  9   Sleeve           500 non-null    str
#  10  Neckline         500 non-null    str
#  11  Pattern          500 non-null    str
#  12  Fabric           500 non-null    str
#  13  Occasion         500 non-null    str
#  14  Recommendation   500 non-null    str
#  15  Height_cm        500 non-null    float64
# dtypes: float64(2), int64(3), str(11)
# memory usage: 99.5 KB

# %%
numeric_columns = [
    "Height_cm",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio"
]

for column in numeric_columns:
    if column in df.columns:
        df[column] = pd.to_numeric(df[column], errors="coerce")

# %%
df.to_csv(
    "../dataset/StyleMate_cleaned.csv",
    index=False
)

print("Cleaned dataset saved successfully.")
# Out:
# Cleaned dataset saved successfully.

# %%
print(df.isnull().sum())
# Out:
# Image_ID           0
# Body_Shape         0
# Shoulder_cm        0
# Waist_cm           0
# Hip_cm             0
# Hip_Waist_Ratio    0
# Colour_Palette     0
# Garment_Type       0
# Garment_Colour     0
# Sleeve             0
# Neckline           0
# Pattern            0
# Fabric             0
# Occasion           0
# Recommendation     0
# Height_cm          0
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
for column in df.columns:
    print(column)
# Out:
# Image_ID
# Body_Shape
# Shoulder_cm
# Waist_cm
# Hip_cm
# Hip_Waist_Ratio
# Colour_Palette
# Garment_Type
# Garment_Colour
# Sleeve
# Neckline
# Pattern
# Fabric
# Occasion
# Recommendation
# Height_cm

# %%
print("Body Shapes:")
print(df["Body_Shape"].value_counts())

print("\nColour Palettes:")
print(df["Colour_Palette"].value_counts())

print("\nGarment Types:")
print(df["Garment_Type"].value_counts())

print("\nGarment Colours:")
print(df["Garment_Colour"].value_counts())
# Out:
# Body Shapes:
# Body_Shape
# Inverted Triangle    120
# Rectangle            112
# Pear                  94
# Apple                 93
# Hourglass             81
# Name: count, dtype: int64
#
# Colour Palettes:
# Colour_Palette
# Neutral    177
# Cool       167
# Warm       156
# Name: count, dtype: int64
#
# Garment Types:
# Garment_Type
# Skirt       63
# Shirt       58
# Trousers    55
# Sweater     54
# Blouse      53
# Kurti       51
# Dress       48
# Jeans       44
# Jacket      40
# T-Shirt     34
# Name: count, dtype: int64
#
# Garment Colours:
# Garment_Colour
# White        47
# Yellow       39
# Brown        36
# Maroon       36
# Peach        36
# Grey         35
# Green        34
# Red          33
# Beige        33
# Navy Blue    31
# Lavender     30
# Pink         29
# Sky Blue     28
# Olive        28
# Black        25
# Name: count, dtype: int64

# %%
text_columns = df.select_dtypes(include="object").columns

for column in text_columns:
    df[column] = df[column].str.strip()
# Out:
# C:\Users\Krupa P\AppData\Local\Temp\ipykernel_12268\2819871510.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   text_columns = df.select_dtypes(include="object").columns

# %%
df["Body_Shape"] = df["Body_Shape"].str.title()
df["Colour_Palette"] = df["Colour_Palette"].str.title()
df["Garment_Type"] = df["Garment_Type"].str.title()
df["Garment_Colour"] = df["Garment_Colour"].str.title()

# %%
print(df["Body_Shape"].unique())
print(df["Colour_Palette"].unique())
print(df["Garment_Type"].unique())
print(df["Garment_Colour"].unique())
# Out:
# <ArrowStringArray>
# ['Rectangle', 'Pear', 'Hourglass', 'Apple', 'Inverted Triangle']
# Length: 5, dtype: str
# <ArrowStringArray>
# ['Warm', 'Neutral', 'Cool']
# Length: 3, dtype: str
# <ArrowStringArray>
# [  'Blouse',  'Sweater',    'Shirt', 'Trousers',    'Kurti',    'Skirt',
#     'Jeans',    'Dress',  'T-Shirt',   'Jacket']
# Length: 10, dtype: str
# <ArrowStringArray>
# [ 'Sky Blue',     'Brown',    'Maroon',       'Red',     'White',     'Beige',
#       'Grey', 'Navy Blue',     'Olive',    'Yellow',      'Pink',     'Peach',
#      'Black',     'Green',  'Lavender']
# Length: 15, dtype: str

# %%
df.to_csv(
    "../dataset/StyleMate_cleaned.csv",
    index=False
)

print("Categorical data cleaned and saved.")
# Out:
# Categorical data cleaned and saved.

# %%
import matplotlib.pyplot as plt

# %%
df["Body_Shape"].value_counts().plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Number of Records by Body Shape")
plt.xlabel("Body Shape")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.show()

# %%
df["Colour_Palette"].value_counts().plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Distribution of Colour Palettes")
plt.xlabel("Colour Palette")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.show()

# %%
df["Garment_Type"].value_counts().plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Distribution of Garment Types")
plt.xlabel("Garment Type")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.show()

# %%
df["Garment_Colour"].value_counts().plot(
    kind="bar",
    figsize=(10, 5)
)

plt.title("Distribution of Garment Colours")
plt.xlabel("Garment Colour")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.hist(df["Height_cm"], bins=10)

plt.title("Height Distribution")
plt.xlabel("Height in cm")
plt.ylabel("Number of Records")
plt.show()

# %%
df[
    ["Height_cm", "Shoulder_cm", "Waist_cm", "Hip_cm"]
].describe()
# Out:
#         Height_cm  Shoulder_cm    Waist_cm      Hip_cm
# count  500.000000   500.000000  500.000000  500.000000
# mean   165.056600    41.316000   33.084000   41.054000
# std      7.767899     4.346715    4.414058    4.141665
# min    145.000000    34.000000   26.000000   34.000000
# 25%    159.400000    37.000000   29.000000   37.000000
# 50%    165.100000    41.000000   33.000000   41.000000
# 75%    170.125000    45.000000   37.000000   45.000000
# max    190.000000    48.000000   40.000000   48.000000

# %%
df.to_csv(
    "../dataset/StyleMate_cleaned.csv",
    index=False
)

print("Dataset analysis completed and file saved.")
# Out:
# Dataset analysis completed and file saved.

# %%
print(df.columns.tolist())
# Out:
# ['Image_ID', 'Body_Shape', 'Shoulder_cm', 'Waist_cm', 'Hip_cm', 'Hip_Waist_Ratio', 'Colour_Palette', 'Garment_Type', 'Garment_Colour', 'Sleeve', 'Neckline', 'Pattern', 'Fabric', 'Occasion', 'Recommendation', 'Height_cm']

# %%
features = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Height_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve"
]

available_features = [
    column for column in features
    if column in df.columns
]

missing_features = [
    column for column in features
    if column not in df.columns
]

print("Available features:", available_features)
print("Missing features:", missing_features)
# Out:
# Available features: ['Body_Shape', 'Shoulder_cm', 'Waist_cm', 'Hip_cm', 'Height_cm', 'Hip_Waist_Ratio', 'Colour_Palette', 'Garment_Type', 'Garment_Colour', 'Sleeve']
# Missing features: []

# %%
X = df[available_features].copy()

# %%
X.head()
# Out:
#   Body_Shape  Shoulder_cm  Waist_cm  Hip_cm  Height_cm  Hip_Waist_Ratio  \
# 0  Rectangle           44        27      34      169.0             1.26
# 1       Pear           34        26      35      163.9             1.35
# 2  Rectangle           37        33      43      170.2             1.30
# 3  Hourglass           35        27      40      177.2             1.48
# 4      Apple           48        32      35      163.1             1.09
#
#   Colour_Palette Garment_Type Garment_Colour      Sleeve
# 0           Warm       Blouse       Sky Blue  Sleeveless
# 1        Neutral      Sweater       Sky Blue  Sleeveless
# 2           Warm       Blouse          Brown         3/4
# 3           Cool      Sweater         Maroon        Half
# 4        Neutral      Sweater            Red        Half

# %%
categorical_columns = X.select_dtypes(
    include="object"
).columns

print(categorical_columns.tolist())
# Out:
# ['Body_Shape', 'Colour_Palette', 'Garment_Type', 'Garment_Colour', 'Sleeve']
# C:\Users\Krupa P\AppData\Local\Temp\ipykernel_12268\2152505833.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = X.select_dtypes(

# %%
X_encoded = pd.get_dummies(
    X,
    columns=categorical_columns,
    dtype=int
)

# %%
X_encoded.head()
# Out:
#    Shoulder_cm  Waist_cm  Hip_cm  Height_cm  Hip_Waist_Ratio  \
# 0           44        27      34      169.0             1.26
# 1           34        26      35      163.9             1.35
# 2           37        33      43      170.2             1.30
# 3           35        27      40      177.2             1.48
# 4           48        32      35      163.1             1.09
#
#    Body_Shape_Apple  Body_Shape_Hourglass  Body_Shape_Inverted Triangle  \
# 0                 0                     0                             0
# 1                 0                     0                             0
# 2                 0                     0                             0
# 3                 0                     1                             0
# 4                 1                     0                             0
#
#    Body_Shape_Pear  Body_Shape_Rectangle  ...  Garment_Colour_Red  \
# 0                0                     1  ...                   0
# ...

# %%
print("Original feature shape:", X.shape)
print("Encoded feature shape:", X_encoded.shape)
# Out:
# Original feature shape: (500, 10)
# Encoded feature shape: (500, 44)

# %%
print(X_encoded.isnull().sum().sum())
# Out:
# 0

# %%
if "Compatibility_Score" in df.columns:
    print("Target column is available.")
else:
    print("Compatibility_Score is not available.")
# Out:
# Compatibility_Score is not available.

# %%
y = df["Compatibility_Score"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Image_ID', 'Body_Shape', 'Shoulder_cm', 'Waist_cm', 'Hip_cm', 'Hip_Waist_Ratio', 'Colour_Palette', 'Garment_Type', 'Garment_Colour', 'Sleeve', 'Neckline', 'Pattern', 'Fabric', 'Occasion', 'Recommendation', 'Height_cm']

# %%
def calculate_score(row):
    score = 50

    # Body-shape matching
    if row["Body_Shape"] in [
        "Pear",
        "Rectangle",
        "Hourglass",
        "Apple",
        "Inverted Triangle"
    ]:
        score += 15

    # Colour information available
    if pd.notna(row["Colour_Palette"]):
        score += 15

    # Garment information available
    if pd.notna(row["Garment_Type"]):
        score += 10

    # Garment colour available
    if pd.notna(row["Garment_Colour"]):
        score += 10

    return min(score, 100)

# %%
print(df["Compatibility_Score"].describe())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Image_ID', 'Body_Shape', 'Shoulder_cm', 'Waist_cm', 'Hip_cm', 'Hip_Waist_Ratio', 'Colour_Palette', 'Garment_Type', 'Garment_Colour', 'Sleeve', 'Neckline', 'Pattern', 'Fabric', 'Occasion', 'Recommendation', 'Height_cm']

# %%
for column in df.columns:
    print(column)
# Out:
# Image_ID
# Body_Shape
# Shoulder_cm
# Waist_cm
# Hip_cm
# Hip_Waist_Ratio
# Colour_Palette
# Garment_Type
# Garment_Colour
# Sleeve
# Neckline
# Pattern
# Fabric
# Occasion
# Recommendation
# Height_cm

# %%
features = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Height_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve"
]

for column in features:
    if column in df.columns:
        print("Available:", column)
    else:
        print("Missing:", column)
# Out:
# Available: Body_Shape
# Available: Shoulder_cm
# Available: Waist_cm
# Available: Hip_cm
# Available: Height_cm
# Available: Hip_Waist_Ratio
# Available: Colour_Palette
# Available: Garment_Type
# Available: Garment_Colour
# Available: Sleeve

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns.tolist())
# Out:
# ['Image_ID', 'Body_Shape', 'Shoulder_cm', 'Waist_cm', 'Hip_cm', 'Hip_Waist_Ratio', 'Colour_Palette', 'Garment_Type', 'Garment_Colour', 'Sleeve', 'Neckline', 'Pattern', 'Fabric', 'Occasion', 'Recommendation', 'Height_cm']

# %%
print("Body Shapes:")
print(df["Body_Shape"].unique())

print("\nGarment Types:")
print(df["Garment_Type"].unique())

print("\nColour Palettes:")
print(df["Colour_Palette"].unique())

print("\nGarment Colours:")
print(df["Garment_Colour"].unique())

print("\nSleeves:")
print(df["Sleeve"].unique())
# Out:
# Body Shapes:
# <ArrowStringArray>
# ['Rectangle', 'Pear', 'Hourglass', 'Apple', 'Inverted Triangle']
# Length: 5, dtype: str
#
# Garment Types:
# <ArrowStringArray>
# [  'Blouse',  'Sweater',    'Shirt', 'Trousers',    'Kurti',    'Skirt',
#     'Jeans',    'Dress',  'T-Shirt',   'Jacket']
# Length: 10, dtype: str
#
# Colour Palettes:
# <ArrowStringArray>
# ['Warm', 'Neutral', 'Cool']
# Length: 3, dtype: str
#
# Garment Colours:
# <ArrowStringArray>
# [ 'Sky Blue',     'Brown',    'Maroon',       'Red',     'White',     'Beige',
#       'Grey', 'Navy Blue',     'Olive',    'Yellow',      'Pink',     'Peach',
#      'Black',     'Green',  'Lavender']
# Length: 15, dtype: str
#
# Sleeves:
# <ArrowStringArray>
# ['Sleeveless', '3/4', 'Half', 'Full', '-', 'Short']
# Length: 6, dtype: str

# %%
import pandas as pd

def compatibility_score(row):
    score = 50

    body = row["Body_Shape"]
    garment = row["Garment_Type"]
    palette = row["Colour_Palette"]
    colour = row["Garment_Colour"]

    # Body-shape and garment compatibility
    body_rules = {
        "Rectangle": ["Blouse", "Dress", "Skirt", "Jacket", "Kurti"],
        "Pear": ["Blouse", "Kurti", "Jacket", "Shirt"],
        "Hourglass": ["Dress", "Blouse", "Shirt", "Kurti", "Skirt"],
        "Apple": ["Dress", "Blouse", "Shirt", "Jacket"],
        "Inverted Triangle": ["Skirt", "Trouser", "Dress", "Kurti"]
    }

    if garment in body_rules.get(body, []):
        score += 20

    # Colour compatibility
    warm_colours = ["Brown", "Maroon", "Red", "Beige", "Olive", "Yellow", "Peach"]
    cool_colours = ["Navy Blue", "Grey", "Pink", "Green", "Lavender", "White"]

    if palette == "Warm" and colour in warm_colours:
        score += 15
    elif palette == "Cool" and colour in cool_colours:
        score += 15
    elif palette == "Neutral":
        score += 10

    return min(score, 100)

df["Compatibility_Score"] = df.apply(compatibility_score, axis=1)

print(df[[
    "Body_Shape",
    "Garment_Type",
    "Colour_Palette",
    "Garment_Colour",
    "Compatibility_Score"
]].head(10))
# Out:
#           Body_Shape Garment_Type Colour_Palette Garment_Colour  \
# 0          Rectangle       Blouse           Warm       Sky Blue
# 1               Pear      Sweater        Neutral       Sky Blue
# 2          Rectangle       Blouse           Warm          Brown
# 3          Hourglass      Sweater           Cool         Maroon
# 4              Apple      Sweater        Neutral            Red
# 5          Rectangle        Shirt           Warm          White
# 6          Rectangle        Shirt        Neutral          Beige
# 7              Apple     Trousers        Neutral       Sky Blue
# 8               Pear     Trousers        Neutral           Grey
# 9  Inverted Triangle       Blouse           Cool      Navy Blue
#
#    Compatibility_Score
# 0                   70
# 1                   60
# 2                   85
# 3                   50
# 4                   60
# 5                   50
# 6                   60
# 7                   60
# 8                   60
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

features = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Height_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve"
]

X = df[features].copy()
y = df["Compatibility_Score"]

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (500, 10)
# y shape: (500,)

# %%
# !pip install scikit-learn
# Out:
# ...
#   Using cached scipy-1.18.1-cp312-cp312-win_amd64.whl.metadata (61 kB)
# ...
#   Using cached joblib-1.6.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.3 MB 985.5 kB/s eta 0:00:08
#    --- ------------------------------------ 0.8/8.3 MB 985.5 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/8.3 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.3/8.3 MB 1.2 MB/s eta 0:00:06
#    -------- ------------------------------- 1.8/8.3 MB 1.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.3 MB 1.5 MB/s eta 0:00:05
#    ------------- -------------------------- 2.9/8.3 MB 1.6 MB/s eta 0:00:04
# ...

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.9.1

# %%
y_pred = model.predict(X_test)

print("Actual scores:")
print(y_test.values[:10])

print("\nPredicted scores:")
print(y_pred[:10])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 y_pred = model.predict(X_test)
#       2
#       3 print("Actual scores:")
#       4 print(y_test.values[:10])
#
# NameError: name 'model' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

model.fit(X_train, y_train)

print("Model trained successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 8
#       4     n_estimators=100,
#       5     random_state=42
#       6 )
#       7
# ----> 8 model.fit(X_train, y_train)
#       9
#      10 print("Model trained successfully!")
#
# NameError: name 'X_train' is not defined

# %%
features = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Height_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve"
]

X = df[features].copy()
y = df["Compatibility_Score"]

print("X and y created!")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[117], line 14
#      10     "Garment_Colour",
#      11     "Sleeve"
#      12 ]
#      13
# ---> 14 X = df[features].copy()
#      15 y = df["Compatibility_Score"]
#      16
#      17 print("X and y created!")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Image_ID', 'Body_Shape', 'Shoulder_cm', 'Waist_cm', 'Hip_cm', 'Hip_Waist_Ratio', 'Colour_Palette', 'Garment_Type', 'Garment_Colour', 'Sleeve', 'Neckline', 'Pattern', 'Fabric', 'Occasion', 'Recommendation']

# %%
import numpy as np

np.random.seed(42)

df["Height_cm"] = np.random.normal(
    loc=165,
    scale=8,
    size=len(df)
).round(1)

df["Height_cm"] = df["Height_cm"].clip(145, 190)

print(df[["Image_ID", "Height_cm"]].head())
# Out:
#   Image_ID  Height_cm
# 0  IMG_001      169.0
# 1  IMG_002      163.9
# 2  IMG_003      170.2
# 3  IMG_004      177.2
# 4  IMG_005      163.1

# %%
features = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Height_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve"
]

for col in features:
    print(col, "✓" if col in df.columns else "❌ MISSING")
# Out:
# Body_Shape ✓
# Shoulder_cm ✓
# Waist_cm ✓
# Hip_cm ✓
# Height_cm ✓
# Hip_Waist_Ratio ✓
# Colour_Palette ✓
# Garment_Type ✓
# Garment_Colour ✓
# Sleeve ✓

# %%
features = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Height_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve"
]

X = df[features].copy()
y = df["Compatibility_Score"]

print("X and y created successfully!")
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X and y created successfully!
# X shape: (500, 10)
# y shape: (500,)

# %%
import pandas as pd

def compatibility_score(row):

    score = 50

    body = row["Body_Shape"]
    garment = row["Garment_Type"]
    palette = row["Colour_Palette"]
    colour = row["Garment_Colour"]

    # Body shape + garment compatibility
    body_rules = {
        "Rectangle": ["Blouse", "Dress", "Skirt", "Jacket", "Kurti"],
        "Pear": ["Blouse", "Kurti", "Jacket", "Shirt"],
        "Hourglass": ["Dress", "Blouse", "Shirt", "Kurti", "Skirt"],
        "Apple": ["Dress", "Blouse", "Shirt", "Jacket"],
        "Inverted Triangle": ["Skirt", "Trousers", "Dress", "Kurti"]
    }

    if garment in body_rules.get(body, []):
        score += 20

    # Colour compatibility
    warm_colours = [
        "Brown", "Maroon", "Red", "Beige",
        "Olive", "Yellow", "Peach"
    ]

    cool_colours = [
        "Navy Blue", "Grey", "Pink",
        "Green", "Lavender", "White"
    ]

    if palette == "Warm" and colour in warm_colours:
        score += 15

    elif palette == "Cool" and colour in cool_colours:
        score += 15

    elif palette == "Neutral":
        score += 10

    return min(score, 100)


df["Compatibility_Score"] = df.apply(
    compatibility_score,
    axis=1
)

print(df[[
    "Body_Shape",
    "Garment_Type",
    "Colour_Palette",
    "Garment_Colour",
    "Compatibility_Score"
]].head(10))
# Out:
#           Body_Shape Garment_Type Colour_Palette Garment_Colour  \
# 0          Rectangle       Blouse           Warm       Sky Blue
# 1               Pear      Sweater        Neutral       Sky Blue
# 2          Rectangle       Blouse           Warm          Brown
# 3          Hourglass      Sweater           Cool         Maroon
# 4              Apple      Sweater        Neutral            Red
# 5          Rectangle        Shirt           Warm          White
# 6          Rectangle        Shirt        Neutral          Beige
# 7              Apple     Trousers        Neutral       Sky Blue
# 8               Pear     Trousers        Neutral           Grey
# 9  Inverted Triangle       Blouse           Cool      Navy Blue
#
#    Compatibility_Score
# 0                   70
# 1                   60
# 2                   85
# 3                   50
# 4                   60
# 5                   50
# 6                   60
# 7                   60
# 8                   60
# ...

# %%
print("Compatibility_Score" in df.columns)
# Out:
# True

# %%
print(df["Compatibility_Score"].value_counts())
# Out:
# Compatibility_Score
# 60    101
# 50     90
# 85     80
# 65     77
# 70     76
# 80     76
# Name: count, dtype: int64

# %%
features = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Height_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve"
]

X = df[features].copy()
y = df["Compatibility_Score"]

print("X created:", X.shape)
print("y created:", y.shape)
# Out:
# X created: (500, 10)
# y created: (500,)

# %%
import pandas as pd

categorical_columns = X.select_dtypes(include="object").columns

X_encoded = pd.get_dummies(
    X,
    columns=categorical_columns,
    dtype=int
)

print("Encoding completed!")
print("Encoded X shape:", X_encoded.shape)
# Out:
# Encoding completed!
# Encoded X shape: (500, 44)
# C:\Users\Krupa P\AppData\Local\Temp\ipykernel_12268\1080632683.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = X.select_dtypes(include="object").columns

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.2,
    random_state=42
)

print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (400, 44)
# X_test: (100, 44)
# y_train: (400,)
# y_test: (100,)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

model.fit(X_train, y_train)

print("Model trained successfully! ✅")
# Out:
# Model trained successfully! ✅

# %%
y_pred = model.predict(X_test)

print("Predictions:")
print(y_pred[:10])
# Out:
# Predictions:
# [69.2  72.1  63.05 60.45 59.7  73.7  59.8  59.7  73.15 60.6 ]

# %%
comparison = pd.DataFrame({
    "Actual Score": y_test.values,
    "Predicted Score": y_pred.round(2)
})

print(comparison.head(10))
# Out:
#    Actual Score  Predicted Score
# 0            70            69.20
# 1            70            72.10
# 2            50            63.05
# 3            65            60.45
# 4            60            59.70
# 5            85            73.70
# 6            60            59.80
# 7            50            59.70
# 8            70            73.15
# 9            60            60.60

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error (MAE):", round(mae, 2))
print("Mean Squared Error (MSE):", round(mse, 2))
print("Root Mean Squared Error (RMSE):", round(rmse, 2))
print("R² Score:", round(r2, 2))
# Out:
# Mean Absolute Error (MAE): 6.6
# Mean Squared Error (MSE): 64.61
# Root Mean Squared Error (RMSE): 8.04
# R² Score: 0.54

# %%
import matplotlib.pyplot as plt
import pandas as pd

importance = pd.Series(
    model.feature_importances_,
    index=X_encoded.columns
).sort_values(ascending=False)

print(importance.head(10))
# Out:
# Height_cm                       0.087494
# Body_Shape_Inverted Triangle    0.082269
# Hip_Waist_Ratio                 0.062069
# Garment_Type_Sweater            0.061539
# Garment_Type_T-Shirt            0.061450
# Garment_Type_Jeans              0.057992
# Shoulder_cm                     0.055424
# Hip_cm                          0.043292
# Waist_cm                        0.037604
# Colour_Palette_Neutral          0.031000
# dtype: float64

# %%
importance.head(10).sort_values().plot(
    kind="barh",
    figsize=(8, 5)
)

plt.title("Top 10 Feature Importance")
plt.xlabel("Importance")
plt.ylabel("Features")
plt.show()

# %%
def recommend_outfits(
    body_shape,
    height,
    shoulder,
    waist,
    hip,
    colour_palette,
    sleeve
):
    
    # Calculate hip-waist ratio
    hip_waist_ratio = hip / waist

    # Copy dataset
    recommendations = df.copy()

    # Calculate similarity score
    recommendations["Match_Score"] = 0

    # Body shape match
    recommendations.loc[
        recommendations["Body_Shape"] == body_shape,
        "Match_Score"
    ] += 30

    # Colour palette match
    recommendations.loc[
        recommendations["Colour_Palette"] == colour_palette,
        "Match_Score"
    ] += 25

    # Sleeve preference
    recommendations.loc[
        recommendations["Sleeve"] == sleeve,
        "Match_Score"
    ] += 15

    # Height similarity
    recommendations["Height_Difference"] = abs(
        recommendations["Height_cm"] - height
    )

    recommendations.loc[
        recommendations["Height_Difference"] <= 5,
        "Match_Score"
    ] += 15

    # Body measurement similarity
    recommendations["Measurement_Difference"] = (
        abs(recommendations["Shoulder_cm"] - shoulder)
        + abs(recommendations["Waist_cm"] - waist)
        + abs(recommendations["Hip_cm"] - hip)
    )

    recommendations.loc[
        recommendations["Measurement_Difference"] <= 10,
        "Match_Score"
    ] += 15

    # Sort from highest match to lowest
    recommendations = recommendations.sort_values(
        "Match_Score",
        ascending=False
    )

    return recommendations.head(5)""personalized_fashion_dataset_500 (1).csv""
# Out:
#   Cell In[142], line 66
#     return recommendations.head(5)""personalized_fashion_dataset_500 (1).csv""
#                                   ^
# SyntaxError: invalid syntax

# %%
def recommend_outfits(
    body_shape,
    height,
    shoulder,
    waist,
    hip,
    colour_palette,
    sleeve
):
    
    # Calculate hip-waist ratio
    hip_waist_ratio = hip / waist

    # Copy dataset
    recommendations = df.copy()

    # Calculate similarity score
    recommendations["Match_Score"] = 0

    # Body shape match
    recommendations.loc[
        recommendations["Body_Shape"] == body_shape,
        "Match_Score"
    ] += 30

    # Colour palette match
    recommendations.loc[
        recommendations["Colour_Palette"] == colour_palette,
        "Match_Score"
    ] += 25

    # Sleeve preference
    recommendations.loc[
        recommendations["Sleeve"] == sleeve,
        "Match_Score"
    ] += 15

    # Height similarity
    recommendations["Height_Difference"] = abs(
        recommendations["Height_cm"] - height
    )

    recommendations.loc[
        recommendations["Height_Difference"] <= 5,
        "Match_Score"
    ] += 15

    # Body measurement similarity
    recommendations["Measurement_Difference"] = (
        abs(recommendations["Shoulder_cm"] - shoulder)
        + abs(recommendations["Waist_cm"] - waist)
        + abs(recommendations["Hip_cm"] - hip)
    )

    recommendations.loc[
        recommendations["Measurement_Difference"] <= 10,
        "Match_Score"
    ] += 15

    # Sort from highest match to lowest
    recommendations = recommendations.sort_values(
        "Match_Score",
        ascending=False
    )

    return recommendations.head(5)

# %%
result = recommend_outfits(
    body_shape="Pear",
    height=165,
    shoulder=36,
    waist=28,
    hip=38,
    colour_palette="Warm",
    sleeve="Full"
)

print(result[[
    "Garment_Type",
    "Garment_Colour",
    "Body_Shape",
    "Colour_Palette",
    "Sleeve",
    "Match_Score"
]])
# Out:
#     Garment_Type Garment_Colour Body_Shape Colour_Palette Sleeve  Match_Score
# 332       Blouse          White       Pear           Warm   Full          100
# 349        Kurti          Brown       Pear           Warm   Half           85
# 407        Jeans       Lavender       Pear           Warm      -           85
# 81        Jacket          Black       Pear           Cool   Full           75
# 278        Kurti          Green       Pear        Neutral   Full           75

# %%
pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.to_csv("../dataset/StyleMate_cleaned.csv", index=False)

print("Dataset saved successfully! ✅")
# Out:
# Dataset saved successfully! ✅

# %%
import os

print(os.path.exists("../dataset/StyleMate_cleaned.csv"))
# Out:
# True

# %%
saved_df = pd.read_csv("../dataset/StyleMate_cleaned.csv")

print(saved_df.shape)
print(saved_df.columns.tolist())
# Out:
# (500, 17)
# ['Image_ID', 'Body_Shape', 'Shoulder_cm', 'Waist_cm', 'Hip_cm', 'Hip_Waist_Ratio', 'Colour_Palette', 'Garment_Type', 'Garment_Colour', 'Sleeve', 'Neckline', 'Pattern', 'Fabric', 'Occasion', 'Recommendation', 'Height_cm', 'Compatibility_Score']

# %%
print(df.columns.tolist())
# Out:
# ['Image_ID', 'Body_Shape', 'Shoulder_cm', 'Waist_cm', 'Hip_cm', 'Hip_Waist_Ratio', 'Colour_Palette', 'Garment_Type', 'Garment_Colour', 'Sleeve', 'Neckline', 'Pattern', 'Fabric', 'Occasion', 'Recommendation']

# %% [markdown]
# print("Number of recommendations:", df["Recommendation"].nunique())
#
# print("\nRecommendation values:")
# print(df["Recommendation"].unique())

# %%
print(df["Recommendation"].value_counts().head(20))
# Out:
# Recommendation
# Layered Outfit           34
# Wide-Leg Trousers        34
# Flowy Dress              29
# A-Line Skirt             29
# V-Neck Top               28
# Peplum Top               28
# Pleated Skirt            27
# Empire-Waist Dress       26
# Straight-Leg Trousers    25
# A-Line Dress             25
# Boat-Neck Top            25
# Dark Bottom              23
# Belted Dress             23
# Wrap Dress               23
# V-Neck Outfit            23
# Belted Outfit            22
# Structured Top           21
# Longline Jacket          19
# High-Waist Trousers      18
# Fitted Dress             18
# Name: count, dtype: int64

# %%
features = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

X = df[features].copy()
y = df["Recommendation"].copy()

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (500, 13)
# y shape: (500,)

# %%
import pandas as pd

categorical_columns = X.select_dtypes(include="object").columns

X_encoded = pd.get_dummies(
    X,
    columns=categorical_columns,
    dtype=int
)

print("Encoding completed!")
print("Encoded X shape:", X_encoded.shape)
# Out:
# Encoding completed!
# Encoded X shape: (500, 69)
# C:\Users\Krupa P\AppData\Local\Temp\ipykernel_6924\1080632683.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = X.select_dtypes(include="object").columns

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (400, 69)
# Testing data: (100, 69)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

model.fit(X_train, y_train)

print("Random Forest Classifier trained successfully! ✅")
# Out:
# Random Forest Classifier trained successfully! ✅

# %%
y_pred = model.predict(X_test)

print("Predictions:")
print(y_pred[:10])
# Out:
# Predictions:
# ['Straight-Leg Trousers' 'Pleated Skirt' 'Pleated Skirt' 'Flowy Dress'
#  'Layered Outfit' 'Layered Outfit' 'Layered Outfit' 'Longline Jacket'
#  'Empire-Waist Dress' 'Boat-Neck Top']

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", round(accuracy * 100, 2), "%")
# Out:
# Accuracy: 22.0 %

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#                        precision    recall  f1-score   support
#
#          A-Line Dress       0.20      0.20      0.20         5
#          A-Line Skirt       0.29      0.33      0.31         6
#          Belted Dress       0.00      0.00      0.00         5
#         Belted Outfit       0.25      0.25      0.25         4
#         Boat-Neck Top       0.25      0.20      0.22         5
#           Dark Bottom       0.40      0.50      0.44         4
#    Empire-Waist Dress       0.22      0.40      0.29         5
#          Fitted Dress       0.00      0.00      0.00         4
#           Flowy Dress       0.00      0.00      0.00         6
#   High-Waist Trousers       0.33      0.25      0.29         4
#        Layered Outfit       0.20      0.29      0.24         7
#       Longline Jacket       0.00      0.00      0.00         4
#            Peplum Top       0.17      0.20      0.18         5
#         Pleated Skirt       0.33      0.40      0.36         5
# ...

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=model.classes_
)

fig, ax = plt.subplots(figsize=(14, 14))

disp.plot(
    ax=ax,
    xticks_rotation=90,
    colorbar=False
)

plt.title("StyleMate Recommendation Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
importance = pd.Series(
    model.feature_importances_,
    index=X_encoded.columns
).sort_values(ascending=False)

print(importance.head(15))
# Out:
# Hip_Waist_Ratio                 0.062466
# Hip_cm                          0.055790
# Waist_cm                        0.051782
# Body_Shape_Inverted Triangle    0.049442
# Shoulder_cm                     0.047945
# Body_Shape_Rectangle            0.047699
# Body_Shape_Apple                0.043478
# Body_Shape_Pear                 0.041762
# Body_Shape_Hourglass            0.036077
# Colour_Palette_Cool             0.014980
# Occasion_Traditional            0.014850
# Colour_Palette_Neutral          0.014618
# Colour_Palette_Warm             0.013531
# Pattern_Floral                  0.013369
# Occasion_Party                  0.013274
# dtype: float64

# %%
import matplotlib.pyplot as plt

importance.head(10).sort_values().plot(
    kind="barh",
    figsize=(8, 5)
)

plt.title("Top 10 Features Used by StyleMate")
plt.xlabel("Feature Importance")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

importance.head(10).sort_values().plot(
    kind="barh",
    figsize=(8, 5)
)

plt.title("Top 10 Features Used by StyleMate")
plt.xlabel("Feature Importance")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %%
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# Image_ID           0
# Body_Shape         0
# Shoulder_cm        0
# Waist_cm           0
# Hip_cm             0
# Hip_Waist_Ratio    0
# Colour_Palette     0
# Garment_Type       0
# Garment_Colour     0
# Sleeve             0
# Neckline           0
# Pattern            0
# Fabric             0
# Occasion           0
# Recommendation     0
# dtype: int64

# %%
print("Total missing values:", df.isnull().sum().sum())
# Out:
# Total missing values: 0

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
df[
    ["Shoulder_cm", "Waist_cm", "Hip_cm", "Hip_Waist_Ratio"]
].describe()
# Out:
#        Shoulder_cm    Waist_cm      Hip_cm  Hip_Waist_Ratio
# count   500.000000  500.000000  500.000000       500.000000
# mean     41.316000   33.084000   41.054000         1.263360
# std       4.346715    4.414058    4.141665         0.213445
# min      34.000000   26.000000   34.000000         0.870000
# 25%      37.000000   29.000000   37.000000         1.100000
# 50%      41.000000   33.000000   41.000000         1.230000
# 75%      45.000000   37.000000   45.000000         1.412500
# max      48.000000   40.000000   48.000000         1.850000

# %%
import matplotlib.pyplot as plt

df["Body_Shape"].value_counts().plot(
    kind="bar",
    figsize=(8,5)
)

plt.title("Distribution of Body Shapes")
plt.xlabel("Body Shape")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df["Recommendation"].value_counts().head(15).plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Top 15 Outfit Recommendations")
plt.xlabel("Recommendation")
plt.ylabel("Number of Records")
plt.xticks(rotation=75)
plt.tight_layout()
plt.show()

# %%
df["Recommendation"].value_counts().head(15).plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Top 15 Outfit Recommendations")
plt.xlabel("Recommendation")
plt.ylabel("Number of Records")
plt.xticks(rotation=75)
plt.tight_layout()
plt.show()

# %%
palette_counts.plot(
    kind="bar",
    figsize=(7, 5)
)

plt.title("Distribution of Colour Palettes")
plt.xlabel("Colour Palette")
plt.ylabel("Number of Records")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
print(df["Colour_Palette"].unique())
# Out:
# <ArrowStringArray>
# ['Warm', 'Neutral', 'Cool']
# Length: 3, dtype: str

# %%
palette_counts = df["Colour_Palette"].value_counts()

print(palette_counts)
# Out:
# Colour_Palette
# Neutral    177
# Cool       167
# Warm       156
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

palette_counts.plot(
    kind="bar",
    figsize=(7, 5)
)

plt.title("Distribution of Colour Palettes")
plt.xlabel("Colour Palette")
plt.ylabel("Number of Records")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
garment_counts = df["Garment_Type"].value_counts()

print(garment_counts)
# Out:
# Garment_Type
# Skirt       63
# Shirt       58
# Trousers    55
# Sweater     54
# Blouse      53
# Kurti       51
# Dress       48
# Jeans       44
# Jacket      40
# T-Shirt     34
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

garment_counts.plot(
    kind="bar",
    figsize=(10, 5)
)

plt.title("Distribution of Garment Types")
plt.xlabel("Garment Type")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
garment_colour_counts = df["Garment_Colour"].value_counts()

print(garment_colour_counts)
# Out:
# Garment_Colour
# White        47
# Yellow       39
# Brown        36
# Maroon       36
# Peach        36
# Grey         35
# Green        34
# Red          33
# Beige        33
# Navy Blue    31
# Lavender     30
# Pink         29
# Sky Blue     28
# Olive        28
# Black        25
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

garment_colour_counts.plot(
    kind="bar",
    figsize=(10, 5)
)

plt.title("Distribution of Garment Colours")
plt.xlabel("Garment Colour")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
occasion_counts = df["Occasion"].value_counts()

print(occasion_counts)
# Out:
# Occasion
# Party          104
# Formal         102
# Traditional    101
# Casual         100
# College         93
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

occasion_counts.plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Distribution of Occasions")
plt.xlabel("Occasion")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sleeve_counts = df["Sleeve"].value_counts()

print(sleeve_counts)
# Out:
# Sleeve
# -             162
# Sleeveless     76
# Half           70
# 3/4            68
# Full           66
# Short          58
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

sleeve_counts.plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Distribution of Sleeve Types")
plt.xlabel("Sleeve Type")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
print(df["Sleeve"].unique())
# Out:
# <ArrowStringArray>
# ['Sleeveless', '3/4', 'Half', 'Full', '-', 'Short']
# Length: 6, dtype: str

# %%
print(df["Sleeve"].value_counts())
# Out:
# Sleeve
# -             162
# Sleeveless     76
# Half           70
# 3/4            68
# Full           66
# Short          58
# Name: count, dtype: int64

# %%
neckline_counts = df["Neckline"].value_counts()

print(neckline_counts)
# Out:
# Neckline
# -             162
# Round          60
# Square         58
# High Neck      51
# V-Neck         49
# Sweetheart     44
# Collar         38
# Boat           38
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

neckline_counts.plot(
    kind="bar",
    figsize=(10, 5)
)

plt.title("Distribution of Neckline Types")
plt.xlabel("Neckline")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
pattern_counts = df["Pattern"].value_counts()

print(pattern_counts)
# Out:
# Pattern
# Striped      90
# Printed      88
# Checked      87
# Floral       84
# Polka Dot    81
# Solid        70
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

pattern_counts.plot(
    kind="bar",
    figsize=(10, 5)
)

plt.title("Distribution of Pattern Types")
plt.xlabel("Pattern")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
fabric_counts = df["Fabric"].value_counts()

print(fabric_counts)
# Out:
# Fabric
# Rayon        77
# Denim        76
# Silk         73
# Wool         71
# Linen        71
# Polyester    68
# Cotton       64
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

fabric_counts.plot(
    kind="bar",
    figsize=(10, 5)
)

plt.title("Distribution of Fabric Types")
plt.xlabel("Fabric")
plt.ylabel("Number of Records")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
recommendation_counts = df["Recommendation"].value_counts()

print(recommendation_counts)
# Out:
# Recommendation
# Layered Outfit           34
# Wide-Leg Trousers        34
# Flowy Dress              29
# A-Line Skirt             29
# V-Neck Top               28
# Peplum Top               28
# Pleated Skirt            27
# Empire-Waist Dress       26
# Straight-Leg Trousers    25
# A-Line Dress             25
# Boat-Neck Top            25
# Dark Bottom              23
# Belted Dress             23
# Wrap Dress               23
# V-Neck Outfit            23
# Belted Outfit            22
# Structured Top           21
# Longline Jacket          19
# High-Waist Trousers      18
# Fitted Dress             18
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

recommendation_counts.plot(
    kind="bar",
    figsize=(14, 6)
)

plt.title("Distribution of Outfit Recommendations")
plt.xlabel("Recommendation")
plt.ylabel("Number of Records")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
body_recommendation = pd.crosstab(
    df["Body_Shape"],
    df["Recommendation"]
)

print(body_recommendation)
# Out:
# Recommendation     A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Body_Shape
# Apple                         0             0             0              0
# Hourglass                     0             0             0             22
# Inverted Triangle             0            29             0              0
# Pear                         25             0             0              0
# Rectangle                     0             0            23              0
#
# Recommendation     Boat-Neck Top  Dark Bottom  Empire-Waist Dress  \
# Body_Shape
# Apple                          0            0                  26
# Hourglass                      0            0                   0
# Inverted Triangle              0            0                   0
# Pear                          25           23                   0
# Rectangle                      0            0                   0
#
# Recommendation     Fitted Dress  Flowy Dress  High-Waist Trousers  \
# Body_Shape
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 7))

plt.imshow(body_recommendation, aspect="auto")

plt.colorbar(label="Number of Records")

plt.xticks(
    range(len(body_recommendation.columns)),
    body_recommendation.columns,
    rotation=90
)

plt.yticks(
    range(len(body_recommendation.index)),
    body_recommendation.index
)

plt.xlabel("Recommendation")
plt.ylabel("Body Shape")
plt.title("Body Shape vs Outfit Recommendation")

plt.tight_layout()
plt.show()

# %%
palette_recommendation = pd.crosstab(
    df["Colour_Palette"],
    df["Recommendation"]
)

print(palette_recommendation)
# Out:
# Recommendation  A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Colour_Palette
# Cool                       6            12            12              6
# Neutral                   10             9             7              5
# Warm                       9             8             4             11
#
# Recommendation  Boat-Neck Top  Dark Bottom  Empire-Waist Dress  Fitted Dress  \
# Colour_Palette
# Cool                       11            7                   9             6
# Neutral                     7            8                  11             7
# Warm                        7            8                   6             5
#
# Recommendation  Flowy Dress  High-Waist Trousers  Layered Outfit  \
# Colour_Palette
# Cool                      8                    4              10
# Neutral                  13                    7              12
# Warm                      8                    7              12
#
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 5))

plt.imshow(palette_recommendation, aspect="auto")

plt.colorbar(label="Number of Records")

plt.xticks(
    range(len(palette_recommendation.columns)),
    palette_recommendation.columns,
    rotation=90
)

plt.yticks(
    range(len(palette_recommendation.index)),
    palette_recommendation.index
)

plt.xlabel("Recommendation")
plt.ylabel("Colour Palette")
plt.title("Colour Palette vs Outfit Recommendation")

plt.tight_layout()
plt.show()

# %%
occasion_recommendation = pd.crosstab(
    df["Occasion"],
    df["Recommendation"]
)

print(occasion_recommendation)
# Out:
# Recommendation  A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Occasion
# Casual                     5             5             3              3
# College                    4             4             4              6
# Formal                     7             6             5              3
# Party                      3             6             5              5
# Traditional                6             8             6              5
#
# Recommendation  Boat-Neck Top  Dark Bottom  Empire-Waist Dress  Fitted Dress  \
# Occasion
# Casual                      6            3                   3             4
# College                     4            5                   4             3
# Formal                      4           10                   8             2
# Party                       4            2                   7             3
# Traditional                 7            3                   4             6
#
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.imshow(occasion_recommendation, aspect="auto")

plt.colorbar(label="Number of Records")

plt.xticks(
    range(len(occasion_recommendation.columns)),
    occasion_recommendation.columns,
    rotation=90
)

plt.yticks(
    range(len(occasion_recommendation.index)),
    occasion_recommendation.index
)

plt.xlabel("Recommendation")
plt.ylabel("Occasion")
plt.title("Occasion vs Outfit Recommendation")

plt.tight_layout()
plt.show()

# %%
occasion_recommendation = pd.crosstab(
    df["Occasion"],
    df["Recommendation"]
)

print(occasion_recommendation)
# Out:
# Recommendation  A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Occasion
# Casual                     5             5             3              3
# College                    4             4             4              6
# Formal                     7             6             5              3
# Party                      3             6             5              5
# Traditional                6             8             6              5
#
# Recommendation  Boat-Neck Top  Dark Bottom  Empire-Waist Dress  Fitted Dress  \
# Occasion
# Casual                      6            3                   3             4
# College                     4            5                   4             3
# Formal                      4           10                   8             2
# Party                       4            2                   7             3
# Traditional                 7            3                   4             6
#
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

plt.imshow(occasion_recommendation, aspect="auto")

plt.colorbar(label="Number of Records")

plt.xticks(
    range(len(occasion_recommendation.columns)),
    occasion_recommendation.columns,
    rotation=90
)

plt.yticks(
    range(len(occasion_recommendation.index)),
    occasion_recommendation.index
)

plt.xlabel("Recommendation")
plt.ylabel("Occasion")
plt.title("Occasion vs Outfit Recommendation")

plt.tight_layout()
plt.show()

# %%
garment_recommendation = pd.crosstab(
    df["Garment_Type"],
    df["Recommendation"]
)

print(garment_recommendation)
# Out:
# Recommendation  A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Garment_Type
# Blouse                     3             3             5              1
# Dress                      1             2             3              3
# Jacket                     1             2             3              4
# Jeans                      3             4             4              3
# Kurti                      3             3             2              1
# Shirt                      4             1             1              3
# Skirt                      4             3             1              2
# Sweater                    1             6             3              3
# T-Shirt                    2             4             1              1
# Trousers                   3             1             0              1
#
# Recommendation  Boat-Neck Top  Dark Bottom  Empire-Waist Dress  Fitted Dress  \
# Garment_Type
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 7))

plt.imshow(garment_recommendation, aspect="auto")

plt.colorbar(label="Number of Records")

plt.xticks(
    range(len(garment_recommendation.columns)),
    garment_recommendation.columns,
    rotation=90
)

plt.yticks(
    range(len(garment_recommendation.index)),
    garment_recommendation.index
)

plt.xlabel("Recommendation")
plt.ylabel("Garment Type")
plt.title("Garment Type vs Outfit Recommendation")

plt.tight_layout()
plt.show()

# %%
numeric_columns = [
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio"
]

correlation = df[numeric_columns].corr()

print(correlation)
# Out:
#                  Shoulder_cm  Waist_cm    Hip_cm  Hip_Waist_Ratio
# Shoulder_cm         1.000000  0.087603 -0.006961        -0.073442
# Waist_cm            0.087603  1.000000  0.025731        -0.789837
# Hip_cm             -0.006961  0.025731  1.000000         0.580787
# Hip_Waist_Ratio    -0.073442 -0.789837  0.580787         1.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 6))

plt.imshow(correlation, cmap="coolwarm", vmin=-1, vmax=1)

plt.colorbar(label="Correlation")

plt.xticks(
    range(len(correlation.columns)),
    correlation.columns,
    rotation=45
)

plt.yticks(
    range(len(correlation.index)),
    correlation.index
)

plt.title("Correlation Between Body Measurements")

plt.tight_layout()
plt.show()

# %%
print("Dataset shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nMissing values:")
print(df.isnull().sum())

print("\nDuplicate rows:")
print(df.duplicated().sum())
# Out:
# Dataset shape: (500, 15)
#
# Columns:
# ['Image_ID', 'Body_Shape', 'Shoulder_cm', 'Waist_cm', 'Hip_cm', 'Hip_Waist_Ratio', 'Colour_Palette', 'Garment_Type', 'Garment_Colour', 'Sleeve', 'Neckline', 'Pattern', 'Fabric', 'Occasion', 'Recommendation']
#
# Missing values:
# Image_ID           0
# Body_Shape         0
# Shoulder_cm        0
# Waist_cm           0
# Hip_cm             0
# Hip_Waist_Ratio    0
# Colour_Palette     0
# Garment_Type       0
# Garment_Colour     0
# Sleeve             0
# Neckline           0
# Pattern            0
# Fabric             0
# Occasion           0
# Recommendation     0
# dtype: int64
#
# Duplicate rows:
# 0

# %%
df.to_csv("StyleMate_cleaned.csv", index=False)

print("Cleaned dataset saved successfully! ✅")
# Out:
# Cleaned dataset saved successfully! ✅

# %%
features = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

X = df[features].copy()
y = df["Recommendation"].copy()

print("Features shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Features shape: (500, 13)
# Target shape: (500,)

# %%
categorical_columns = X.select_dtypes(include="object").columns

X_encoded = pd.get_dummies(
    X,
    columns=categorical_columns,
    dtype=int
)

print("Original shape:", X.shape)
print("Encoded shape:", X_encoded.shape)
# Out:
# Original shape: (500, 13)
# Encoded shape: (500, 69)
# C:\Users\Krupa P\AppData\Local\Temp\ipykernel_6924\2997409245.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = X.select_dtypes(include="object").columns

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

print("Training features:", X_train.shape)
print("Testing features:", X_test.shape)
print("Training target:", y_train.shape)
print("Testing target:", y_test.shape)
# Out:
# Training features: (400, 69)
# Testing features: (100, 69)
# Training target: (400,)
# Testing target: (100,)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

model.fit(X_train, y_train)

print("Random Forest model trained successfully! ✅")
# Out:
# Random Forest model trained successfully! ✅

# %%
v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 v
#
# NameError: name 'v' is not defined

# %%
y_pred = model.predict(X_test)

print("Predictions generated successfully! ✅")
print(y_pred[:10])
# Out:
# Predictions generated successfully! ✅
# ['Straight-Leg Trousers' 'Pleated Skirt' 'Pleated Skirt' 'Flowy Dress'
#  'Layered Outfit' 'Layered Outfit' 'Layered Outfit' 'Longline Jacket'
#  'Empire-Waist Dress' 'Boat-Neck Top']

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy:", round(accuracy * 100, 2), "%")
# Out:
# Model Accuracy: 22.0 %

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#                        precision    recall  f1-score   support
#
#          A-Line Dress       0.20      0.20      0.20         5
#          A-Line Skirt       0.29      0.33      0.31         6
#          Belted Dress       0.00      0.00      0.00         5
#         Belted Outfit       0.25      0.25      0.25         4
#         Boat-Neck Top       0.25      0.20      0.22         5
#           Dark Bottom       0.40      0.50      0.44         4
#    Empire-Waist Dress       0.22      0.40      0.29         5
#          Fitted Dress       0.00      0.00      0.00         4
#           Flowy Dress       0.00      0.00      0.00         6
#   High-Waist Trousers       0.33      0.25      0.29         4
#        Layered Outfit       0.20      0.29      0.24         7
#       Longline Jacket       0.00      0.00      0.00         4
#            Peplum Top       0.17      0.20      0.18         5
#         Pleated Skirt       0.33      0.40      0.36         5
# ...

# %%
print(df["Recommendation"].value_counts())
# Out:
# Recommendation
# Layered Outfit           34
# Wide-Leg Trousers        34
# Flowy Dress              29
# A-Line Skirt             29
# V-Neck Top               28
# Peplum Top               28
# Pleated Skirt            27
# Empire-Waist Dress       26
# Straight-Leg Trousers    25
# A-Line Dress             25
# Boat-Neck Top            25
# Dark Bottom              23
# Belted Dress             23
# Wrap Dress               23
# V-Neck Outfit            23
# Belted Outfit            22
# Structured Top           21
# Longline Jacket          19
# High-Waist Trousers      18
# Fitted Dress             18
# Name: count, dtype: int64

# %%
print(df.groupby("Recommendation")[
    ["Shoulder_cm", "Waist_cm", "Hip_cm", "Hip_Waist_Ratio"]
].mean().round(2))
# Out:
#                        Shoulder_cm  Waist_cm  Hip_cm  Hip_Waist_Ratio
# Recommendation
# A-Line Dress                 40.24     32.56   42.28             1.32
# A-Line Skirt                 40.93     32.76   40.28             1.26
# Belted Dress                 42.04     33.04   41.26             1.27
# Belted Outfit                40.73     33.14   42.86             1.31
# Boat-Neck Top                41.28     36.20   40.44             1.13
# Dark Bottom                  40.35     32.52   39.87             1.25
# Empire-Waist Dress           41.00     30.92   41.58             1.37
# Fitted Dress                 42.06     33.61   39.72             1.20
# Flowy Dress                  42.52     33.62   40.14             1.22
# High-Waist Trousers          41.50     32.56   42.33             1.33
# Layered Outfit               41.32     34.12   41.56             1.24
# Longline Jacket              42.11     33.42   40.79             1.24
# ...

# %%
print(df["Recommendation"].value_counts())
# Out:
# Recommendation
# Layered Outfit           34
# Wide-Leg Trousers        34
# Flowy Dress              29
# A-Line Skirt             29
# V-Neck Top               28
# Peplum Top               28
# Pleated Skirt            27
# Empire-Waist Dress       26
# Straight-Leg Trousers    25
# A-Line Dress             25
# Boat-Neck Top            25
# Dark Bottom              23
# Belted Dress             23
# Wrap Dress               23
# V-Neck Outfit            23
# Belted Outfit            22
# Structured Top           21
# Longline Jacket          19
# High-Waist Trousers      18
# Fitted Dress             18
# Name: count, dtype: int64

# %%
print(df.groupby("Recommendation")[
    ["Shoulder_cm", "Waist_cm", "Hip_cm", "Hip_Waist_Ratio"]
].mean().round(2))
# Out:
#                        Shoulder_cm  Waist_cm  Hip_cm  Hip_Waist_Ratio
# Recommendation
# A-Line Dress                 40.24     32.56   42.28             1.32
# A-Line Skirt                 40.93     32.76   40.28             1.26
# Belted Dress                 42.04     33.04   41.26             1.27
# Belted Outfit                40.73     33.14   42.86             1.31
# Boat-Neck Top                41.28     36.20   40.44             1.13
# Dark Bottom                  40.35     32.52   39.87             1.25
# Empire-Waist Dress           41.00     30.92   41.58             1.37
# Fitted Dress                 42.06     33.61   39.72             1.20
# Flowy Dress                  42.52     33.62   40.14             1.22
# High-Waist Trousers          41.50     32.56   42.33             1.33
# Layered Outfit               41.32     34.12   41.56             1.24
# Longline Jacket              42.11     33.42   40.79             1.24
# ...

# %%
body_recommendation = pd.crosstab(
    df["Body_Shape"],
    df["Recommendation"]
)

print(body_recommendation)
# Out:
# Recommendation     A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Body_Shape
# Apple                         0             0             0              0
# Hourglass                     0             0             0             22
# Inverted Triangle             0            29             0              0
# Pear                         25             0             0              0
# Rectangle                     0             0            23              0
#
# Recommendation     Boat-Neck Top  Dark Bottom  Empire-Waist Dress  \
# Body_Shape
# Apple                          0            0                  26
# Hourglass                      0            0                   0
# Inverted Triangle              0            0                   0
# Pear                          25           23                   0
# Rectangle                      0            0                   0
#
# Recommendation     Fitted Dress  Flowy Dress  High-Waist Trousers  \
# Body_Shape
# ...

# %%
body_recommendation_percentage = pd.crosstab(
    df["Body_Shape"],
    df["Recommendation"],
    normalize="index"
) * 100

print(body_recommendation_percentage.round(1))
# Out:
# Recommendation     A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Body_Shape
# Apple                       0.0           0.0           0.0            0.0
# Hourglass                   0.0           0.0           0.0           27.2
# Inverted Triangle           0.0          24.2           0.0            0.0
# Pear                       26.6           0.0           0.0            0.0
# Rectangle                   0.0           0.0          20.5            0.0
#
# Recommendation     Boat-Neck Top  Dark Bottom  Empire-Waist Dress  \
# Body_Shape
# Apple                        0.0          0.0                28.0
# Hourglass                    0.0          0.0                 0.0
# Inverted Triangle            0.0          0.0                 0.0
# Pear                        26.6         24.5                 0.0
# Rectangle                    0.0          0.0                 0.0
#
# Recommendation     Fitted Dress  Flowy Dress  High-Waist Trousers  \
# Body_Shape
# ...

# %%
body_recommendation_percentage = pd.crosstab(
    df["Body_Shape"],
    df["Recommendation"],
    normalize="index"
) * 100

print(body_recommendation_percentage.round(1))
# Out:
# Recommendation     A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Body_Shape
# Apple                       0.0           0.0           0.0            0.0
# Hourglass                   0.0           0.0           0.0           27.2
# Inverted Triangle           0.0          24.2           0.0            0.0
# Pear                       26.6           0.0           0.0            0.0
# Rectangle                   0.0           0.0          20.5            0.0
#
# Recommendation     Boat-Neck Top  Dark Bottom  Empire-Waist Dress  \
# Body_Shape
# Apple                        0.0          0.0                28.0
# Hourglass                    0.0          0.0                 0.0
# Inverted Triangle            0.0          0.0                 0.0
# Pear                        26.6         24.5                 0.0
# Rectangle                    0.0          0.0                 0.0
#
# Recommendation     Fitted Dress  Flowy Dress  High-Waist Trousers  \
# Body_Shape
# ...

# %%
colour_recommendation = pd.crosstab(
    df["Colour_Palette"],
    df["Recommendation"]
)

print(colour_recommendation)
# Out:
# Recommendation  A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Colour_Palette
# Cool                       6            12            12              6
# Neutral                   10             9             7              5
# Warm                       9             8             4             11
#
# Recommendation  Boat-Neck Top  Dark Bottom  Empire-Waist Dress  Fitted Dress  \
# Colour_Palette
# Cool                       11            7                   9             6
# Neutral                     7            8                  11             7
# Warm                        7            8                   6             5
#
# Recommendation  Flowy Dress  High-Waist Trousers  Layered Outfit  \
# Colour_Palette
# Cool                      8                    4              10
# Neutral                  13                    7              12
# Warm                      8                    7              12
#
# ...

# %%
colour_recommendation_percentage = pd.crosstab(
    df["Colour_Palette"],
    df["Recommendation"],
    normalize="index"
) * 100

print(colour_recommendation_percentage.round(1))
# Out:
# Recommendation  A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Colour_Palette
# Cool                     3.6           7.2           7.2            3.6
# Neutral                  5.6           5.1           4.0            2.8
# Warm                     5.8           5.1           2.6            7.1
#
# Recommendation  Boat-Neck Top  Dark Bottom  Empire-Waist Dress  Fitted Dress  \
# Colour_Palette
# Cool                      6.6          4.2                 5.4           3.6
# Neutral                   4.0          4.5                 6.2           4.0
# Warm                      4.5          5.1                 3.8           3.2
#
# Recommendation  Flowy Dress  High-Waist Trousers  Layered Outfit  \
# Colour_Palette
# Cool                    4.8                  2.4             6.0
# Neutral                 7.3                  4.0             6.8
# Warm                    5.1                  4.5             7.7
#
# ...

# %%
check_columns = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

duplicates_with_different_recommendations = (
    df.groupby(check_columns)["Recommendation"]
      .nunique()
      .sort_values(ascending=False)
)

print(duplicates_with_different_recommendations.head(20))
# Out:
# Body_Shape  Shoulder_cm  Waist_cm  Hip_cm  Hip_Waist_Ratio  Colour_Palette  Garment_Type  Garment_Colour  Sleeve      Neckline    Pattern    Fabric     Occasion
# Apple       34           29        40      1.38             Warm            Shirt         Peach           3/4         Square      Printed    Cotton     Traditional    1
#                          30        37      1.23             Warm            Jacket        Red             Full        High Neck   Floral     Polyester  Traditional    1
#                                    43      1.43             Cool            Jeans         White           -           -           Floral     Wool       Traditional    1
#                          38        41      1.08             Neutral         Dress         Maroon          Short       Round       Striped    Wool       Formal         1
# ...

# %%
check_columns = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

duplicates_with_different_recommendations = (
    df.groupby(check_columns)["Recommendation"]
      .nunique()
      .sort_values(ascending=False)
)

print(duplicates_with_different_recommendations.head(20))
# Out:
# Body_Shape  Shoulder_cm  Waist_cm  Hip_cm  Hip_Waist_Ratio  Colour_Palette  Garment_Type  Garment_Colour  Sleeve      Neckline    Pattern    Fabric     Occasion
# Apple       34           29        40      1.38             Warm            Shirt         Peach           3/4         Square      Printed    Cotton     Traditional    1
#                          30        37      1.23             Warm            Jacket        Red             Full        High Neck   Floral     Polyester  Traditional    1
#                                    43      1.43             Cool            Jeans         White           -           -           Floral     Wool       Traditional    1
#                          38        41      1.08             Neutral         Dress         Maroon          Short       Round       Striped    Wool       Formal         1
# ...

# %%
occasion_recommendation = pd.crosstab(
    df["Occasion"],
    df["Recommendation"]
)

print(occasion_recommendation)
# Out:
# Recommendation  A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Occasion
# Casual                     5             5             3              3
# College                    4             4             4              6
# Formal                     7             6             5              3
# Party                      3             6             5              5
# Traditional                6             8             6              5
#
# Recommendation  Boat-Neck Top  Dark Bottom  Empire-Waist Dress  Fitted Dress  \
# Occasion
# Casual                      6            3                   3             4
# College                     4            5                   4             3
# Formal                      4           10                   8             2
# Party                       4            2                   7             3
# Traditional                 7            3                   4             6
#
# ...

# %%
occasion_recommendation_percentage = pd.crosstab(
    df["Occasion"],
    df["Recommendation"],
    normalize="index"
) * 100

print(occasion_recommendation_percentage.round(1))
# Out:
# Recommendation  A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Occasion
# Casual                   5.0           5.0           3.0            3.0
# College                  4.3           4.3           4.3            6.5
# Formal                   6.9           5.9           4.9            2.9
# Party                    2.9           5.8           4.8            4.8
# Traditional              5.9           7.9           5.9            5.0
#
# Recommendation  Boat-Neck Top  Dark Bottom  Empire-Waist Dress  Fitted Dress  \
# Occasion
# Casual                    6.0          3.0                 3.0           4.0
# College                   4.3          5.4                 4.3           3.2
# Formal                    3.9          9.8                 7.8           2.0
# Party                     3.8          1.9                 6.7           2.9
# Traditional               6.9          3.0                 4.0           5.9
#
# ...

# %%
garment_recommendation = pd.crosstab(
    df["Garment_Type"],
    df["Recommendation"]
)

print(garment_recommendation)
# Out:
# Recommendation  A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Garment_Type
# Blouse                     3             3             5              1
# Dress                      1             2             3              3
# Jacket                     1             2             3              4
# Jeans                      3             4             4              3
# Kurti                      3             3             2              1
# Shirt                      4             1             1              3
# Skirt                      4             3             1              2
# Sweater                    1             6             3              3
# T-Shirt                    2             4             1              1
# Trousers                   3             1             0              1
#
# Recommendation  Boat-Neck Top  Dark Bottom  Empire-Waist Dress  Fitted Dress  \
# Garment_Type
# ...

# %%
check_columns = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

duplicates_with_different_recommendations = (
    df.groupby(check_columns)["Recommendation"]
      .nunique()
      .sort_values(ascending=False)
)

print(duplicates_with_different_recommendations.head(20))
# Out:
# Body_Shape  Shoulder_cm  Waist_cm  Hip_cm  Hip_Waist_Ratio  Colour_Palette  Garment_Type  Garment_Colour  Sleeve      Neckline    Pattern    Fabric     Occasion
# Apple       34           29        40      1.38             Warm            Shirt         Peach           3/4         Square      Printed    Cotton     Traditional    1
#                          30        37      1.23             Warm            Jacket        Red             Full        High Neck   Floral     Polyester  Traditional    1
#                                    43      1.43             Cool            Jeans         White           -           -           Floral     Wool       Traditional    1
#                          38        41      1.08             Neutral         Dress         Maroon          Short       Round       Striped    Wool       Formal         1
# ...

# %%
garment_recommendation_percentage = pd.crosstab(
    df["Garment_Type"],
    df["Recommendation"],
    normalize="index"
) * 100

print(garment_recommendation_percentage.round(1))
# Out:
# Recommendation  A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Garment_Type
# Blouse                   5.7           5.7           9.4            1.9
# Dress                    2.1           4.2           6.2            6.2
# Jacket                   2.5           5.0           7.5           10.0
# Jeans                    6.8           9.1           9.1            6.8
# Kurti                    5.9           5.9           3.9            2.0
# Shirt                    6.9           1.7           1.7            5.2
# Skirt                    6.3           4.8           1.6            3.2
# Sweater                  1.9          11.1           5.6            5.6
# T-Shirt                  5.9          11.8           2.9            2.9
# Trousers                 5.5           1.8           0.0            1.8
#
# Recommendation  Boat-Neck Top  Dark Bottom  Empire-Waist Dress  Fitted Dress  \
# Garment_Type
# ...

# %%
body_shape_counts = pd.crosstab(
    df["Body_Shape"],
    df["Recommendation"]
)

print(body_shape_counts)
# Out:
# Recommendation     A-Line Dress  A-Line Skirt  Belted Dress  Belted Outfit  \
# Body_Shape
# Apple                         0             0             0              0
# Hourglass                     0             0             0             22
# Inverted Triangle             0            29             0              0
# Pear                         25             0             0              0
# Rectangle                     0             0            23              0
#
# Recommendation     Boat-Neck Top  Dark Bottom  Empire-Waist Dress  \
# Body_Shape
# Apple                          0            0                  26
# Hourglass                      0            0                   0
# Inverted Triangle              0            0                   0
# Pear                          25           23                   0
# Rectangle                      0            0                   0
#
# Recommendation     Fitted Dress  Flowy Dress  High-Waist Trousers  \
# Body_Shape
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 6))

plt.imshow(body_shape_counts, aspect="auto")

plt.xticks(
    range(len(body_shape_counts.columns)),
    body_shape_counts.columns,
    rotation=90
)

plt.yticks(
    range(len(body_shape_counts.index)),
    body_shape_counts.index
)

plt.xlabel("Recommendation")
plt.ylabel("Body Shape")
plt.title("Body Shape vs Recommendation")

plt.colorbar(label="Number of Samples")
plt.tight_layout()
plt.show()

# %%
check_columns = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

duplicates_with_different_recommendations = (
    df.groupby(check_columns)["Recommendation"]
      .nunique()
      .sort_values(ascending=False)
)

print(duplicates_with_different_recommendations.head(20))
# Out:
# Body_Shape  Shoulder_cm  Waist_cm  Hip_cm  Hip_Waist_Ratio  Colour_Palette  Garment_Type  Garment_Colour  Sleeve      Neckline    Pattern    Fabric     Occasion
# Apple       34           29        40      1.38             Warm            Shirt         Peach           3/4         Square      Printed    Cotton     Traditional    1
#                          30        37      1.23             Warm            Jacket        Red             Full        High Neck   Floral     Polyester  Traditional    1
#                                    43      1.43             Cool            Jeans         White           -           -           Floral     Wool       Traditional    1
#                          38        41      1.08             Neutral         Dress         Maroon          Short       Round       Striped    Wool       Formal         1
# ...

# %%
check_columns = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

result = (
    df.groupby(check_columns)["Recommendation"]
      .nunique()
      .sort_values(ascending=False)
)

print(result.head(20))
# Out:
# Body_Shape  Shoulder_cm  Waist_cm  Hip_cm  Hip_Waist_Ratio  Colour_Palette  Garment_Type  Garment_Colour  Sleeve      Neckline    Pattern    Fabric     Occasion
# Apple       34           29        40      1.38             Warm            Shirt         Peach           3/4         Square      Printed    Cotton     Traditional    1
#                          30        37      1.23             Warm            Jacket        Red             Full        High Neck   Floral     Polyester  Traditional    1
#                                    43      1.43             Cool            Jeans         White           -           -           Floral     Wool       Traditional    1
#                          38        41      1.08             Neutral         Dress         Maroon          Short       Round       Striped    Wool       Formal         1
# ...

# %%
check_columns = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

duplicates_with_different_recommendations = (
    df.groupby(check_columns)["Recommendation"]
      .nunique()
      .sort_values(ascending=False)
)

print("Number of unique input combinations:",
      len(duplicates_with_different_recommendations))

print("\nInput combinations having multiple recommendations:")
print(
    duplicates_with_different_recommendations[
        duplicates_with_different_recommendations > 1
    ].head(20)
)
# Out:
# Number of unique input combinations: 500
#
# Input combinations having multiple recommendations:
# Series([], Name: Recommendation, dtype: int64)

# %%
conflicting_combinations = (
    duplicates_with_different_recommendations[
        duplicates_with_different_recommendations > 1
    ].index
)

conflicting_rows = df.set_index(check_columns).loc[
    conflicting_combinations
].reset_index()

conflicting_rows = conflicting_rows.sort_values(check_columns)

print("Number of conflicting rows:", len(conflicting_rows))

display(conflicting_rows)
# Out:
# Number of conflicting rows: 0
# Empty DataFrame
# Columns: [Body_Shape, Shoulder_cm, Waist_cm, Hip_cm, Hip_Waist_Ratio, Colour_Palette, Garment_Type, Garment_Colour, Sleeve, Neckline, Pattern, Fabric, Occasion, Image_ID, Recommendation]
# Index: []

# %%
grouped = (
    df.groupby(check_columns)["Recommendation"]
      .agg(
          unique_recommendations="nunique",
          total_rows="size"
      )
)

print("Total input combinations:", len(grouped))

print(
    "Conflicting input combinations:",
    (grouped["unique_recommendations"] > 1).sum()
)

print(
    "Non-conflicting input combinations:",
    (grouped["unique_recommendations"] == 1).sum()
)
# Out:
# Total input combinations: 500
# Conflicting input combinations: 0
# Non-conflicting input combinations: 500

# %%
conflicting_count = (
    grouped["unique_recommendations"] > 1
).sum()

total_combinations = len(grouped)

conflict_percentage = (
    conflicting_count / total_combinations
) * 100

print(f"Conflict percentage: {conflict_percentage:.2f}%")
# Out:
# Conflict percentage: 0.00%

# %%
class_counts = df["Recommendation"].value_counts()

print(class_counts)

print("\nSmallest class:")
print(class_counts.min())

print("\nLargest class:")
print(class_counts.max())

print("\nNumber of classes:")
print(class_counts.nunique())
# Out:
# Recommendation
# Layered Outfit           34
# Wide-Leg Trousers        34
# Flowy Dress              29
# A-Line Skirt             29
# V-Neck Top               28
# Peplum Top               28
# Pleated Skirt            27
# Empire-Waist Dress       26
# Straight-Leg Trousers    25
# A-Line Dress             25
# Boat-Neck Top            25
# Dark Bottom              23
# Belted Dress             23
# Wrap Dress               23
# V-Neck Outfit            23
# Belted Outfit            22
# Structured Top           21
# Longline Jacket          19
# High-Waist Trousers      18
# Fitted Dress             18
# Name: count, dtype: int64
#
# Smallest class:
# 18
#
# Largest class:
# 34
#
# Number of classes:
# 11

# %%
class_counts.plot(
    kind="bar",
    figsize=(14, 6),
    title="Recommendation Class Distribution"
)

plt.xlabel("Recommendation")
plt.ylabel("Number of Samples")
plt.xticks(rotation=75)
plt.tight_layout()
plt.show()

# %%
feature_importance = pd.DataFrame({
    "Feature": X_encoded.columns,
    "Importance": model.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

display(feature_importance.head(20))
# Out:
#                          Feature  Importance
# 3                Hip_Waist_Ratio    0.062466
# 2                         Hip_cm    0.055790
# 1                       Waist_cm    0.051782
# 6   Body_Shape_Inverted Triangle    0.049442
# 0                    Shoulder_cm    0.047945
# 8           Body_Shape_Rectangle    0.047699
# 4               Body_Shape_Apple    0.043478
# 7                Body_Shape_Pear    0.041762
# 5           Body_Shape_Hourglass    0.036077
# 9            Colour_Palette_Cool    0.014980
# 68          Occasion_Traditional    0.014850
# 10        Colour_Palette_Neutral    0.014618
# 11           Colour_Palette_Warm    0.013531
# 52                Pattern_Floral    0.013369
# 67                Occasion_Party    0.013274
# 54               Pattern_Printed    0.012725
# 57                 Fabric_Cotton    0.012325
# 66               Occasion_Formal    0.012317
# 55                 Pattern_Solid    0.012156
# 64               Occasion_Casual    0.012086

# %%
top_features = feature_importance.head(20).sort_values(
    "Importance"
)

top_features.plot(
    x="Feature",
    y="Importance",
    kind="barh",
    figsize=(10, 8),
    legend=False,
    title="Top 20 Random Forest Features"
)

plt.xlabel("Importance")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %%
class_counts = df["Recommendation"].value_counts()

print("Number of recommendation classes:", len(class_counts))
print("\nClass distribution:")
print(class_counts)

print("\nSmallest class:", class_counts.min())
print("Largest class:", class_counts.max())
# Out:
# Number of recommendation classes: 20
#
# Class distribution:
# Recommendation
# Layered Outfit           34
# Wide-Leg Trousers        34
# Flowy Dress              29
# A-Line Skirt             29
# V-Neck Top               28
# Peplum Top               28
# Pleated Skirt            27
# Empire-Waist Dress       26
# Straight-Leg Trousers    25
# A-Line Dress             25
# Boat-Neck Top            25
# Dark Bottom              23
# Belted Dress             23
# Wrap Dress               23
# V-Neck Outfit            23
# Belted Outfit            22
# Structured Top           21
# Longline Jacket          19
# High-Waist Trousers      18
# Fitted Dress             18
# Name: count, dtype: int64
#
# Smallest class: 18
# Largest class: 34

# %%
class_counts.plot(
    kind="bar",
    figsize=(14, 6),
    title="Recommendation Class Distribution"
)

plt.xlabel("Recommendation")
plt.ylabel("Number of Samples")
plt.xticks(rotation=75)
plt.tight_layout()
plt.show()

# %%
feature_importance = pd.DataFrame({
    "Feature": X_encoded.columns,
    "Importance": model.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

display(feature_importance.head(20))
# Out:
#                          Feature  Importance
# 3                Hip_Waist_Ratio    0.062466
# 2                         Hip_cm    0.055790
# 1                       Waist_cm    0.051782
# 6   Body_Shape_Inverted Triangle    0.049442
# 0                    Shoulder_cm    0.047945
# 8           Body_Shape_Rectangle    0.047699
# 4               Body_Shape_Apple    0.043478
# 7                Body_Shape_Pear    0.041762
# 5           Body_Shape_Hourglass    0.036077
# 9            Colour_Palette_Cool    0.014980
# 68          Occasion_Traditional    0.014850
# 10        Colour_Palette_Neutral    0.014618
# 11           Colour_Palette_Warm    0.013531
# 52                Pattern_Floral    0.013369
# 67                Occasion_Party    0.013274
# 54               Pattern_Printed    0.012725
# 57                 Fabric_Cotton    0.012325
# 66               Occasion_Formal    0.012317
# 55                 Pattern_Solid    0.012156
# 64               Occasion_Casual    0.012086

# %%
top_features = feature_importance.head(20).sort_values(
    "Importance"
)

top_features.plot(
    x="Feature",
    y="Importance",
    kind="barh",
    figsize=(10, 8),
    legend=False,
    title="Top 20 Random Forest Features"
)

plt.xlabel("Importance")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(
    y_test,
    y_pred,
    labels=model.classes_
)

fig, ax = plt.subplots(figsize=(14, 14))

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=model.classes_
)

disp.plot(
    ax=ax,
    xticks_rotation=90,
    values_format="d"
)

plt.title("Random Forest Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
v
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 v
#
# NameError: name 'v' is not defined

# %%
from sklearn.metrics import classification_report

report = classification_report(
    y_test,
    y_pred,
    output_dict=True,
    zero_division=0
)

report_df = pd.DataFrame(report).transpose()

display(
    report_df[
        ["precision", "recall", "f1-score", "support"]
    ].sort_values("f1-score", ascending=False)
)
# Out:
#                        precision    recall  f1-score  support
# Dark Bottom             0.400000  0.500000  0.444444     4.00
# Wide-Leg Trousers       0.428571  0.428571  0.428571     7.00
# Pleated Skirt           0.333333  0.400000  0.363636     5.00
# A-Line Skirt            0.285714  0.333333  0.307692     6.00
# Wrap Dress              0.250000  0.400000  0.307692     5.00
# High-Waist Trousers     0.333333  0.250000  0.285714     4.00
# Empire-Waist Dress      0.222222  0.400000  0.285714     5.00
# Structured Top          0.250000  0.250000  0.250000     4.00
# Belted Outfit           0.250000  0.250000  0.250000     4.00
# Layered Outfit          0.200000  0.285714  0.235294     7.00
# Boat-Neck Top           0.250000  0.200000  0.222222     5.00
# accuracy                0.220000  0.220000  0.220000     0.22
# weighted avg            0.189921  0.220000  0.201284   100.00
# A-Line Dress            0.200000  0.200000  0.200000     5.00
# ...

# %%
from sklearn.metrics import classification_report

report = classification_report(
    y_test,
    y_pred,
    output_dict=True,
    zero_division=0
)

report_df = pd.DataFrame(report).transpose()

display(
    report_df[
        ["precision", "recall", "f1-score", "support"]
    ].sort_values("f1-score", ascending=False)
)
# Out:
#                        precision    recall  f1-score  support
# Dark Bottom             0.400000  0.500000  0.444444     4.00
# Wide-Leg Trousers       0.428571  0.428571  0.428571     7.00
# Pleated Skirt           0.333333  0.400000  0.363636     5.00
# A-Line Skirt            0.285714  0.333333  0.307692     6.00
# Wrap Dress              0.250000  0.400000  0.307692     5.00
# High-Waist Trousers     0.333333  0.250000  0.285714     4.00
# Empire-Waist Dress      0.222222  0.400000  0.285714     5.00
# Structured Top          0.250000  0.250000  0.250000     4.00
# Belted Outfit           0.250000  0.250000  0.250000     4.00
# Layered Outfit          0.200000  0.285714  0.235294     7.00
# Boat-Neck Top           0.250000  0.200000  0.222222     5.00
# accuracy                0.220000  0.220000  0.220000     0.22
# weighted avg            0.189921  0.220000  0.201284   100.00
# A-Line Dress            0.200000  0.200000  0.200000     5.00
# ...

# %%
import numpy as np
import pandas as pd

cm_df = pd.DataFrame(
    cm,
    index=model.classes_,
    columns=model.classes_
)

confusions = []

for actual in model.classes_:
    for predicted in model.classes_:
        if actual != predicted and cm_df.loc[actual, predicted] > 0:
            confusions.append({
                "Actual": actual,
                "Predicted": predicted,
                "Count": cm_df.loc[actual, predicted]
            })

confusions_df = pd.DataFrame(confusions)

confusions_df = confusions_df.sort_values(
    "Count",
    ascending=False
)

display(confusions_df.head(15))
# Out:
#                    Actual           Predicted  Count
# 40             V-Neck Top         Flowy Dress      4
# 25         Layered Outfit          Peplum Top      4
# 19           Fitted Dress          Wrap Dress      3
# 27        Longline Jacket  Empire-Waist Dress      3
# 32  Straight-Leg Trousers  Empire-Waist Dress      3
# 31          Pleated Skirt      Layered Outfit      3
# 29             Peplum Top      Layered Outfit      3
# 22            Flowy Dress   Wide-Leg Trousers      2
# 1            A-Line Dress         Dark Bottom      2
# 5            A-Line Skirt   Wide-Leg Trousers      2
# 10          Belted Outfit          Wrap Dress      2
# 11          Boat-Neck Top        A-Line Dress      2
# 8            Belted Dress       Pleated Skirt      2
# 6            Belted Dress      Layered Outfit      2
# 34         Structured Top        A-Line Dress      2

# %%
confusions = []

for actual in model.classes_:
    for predicted in model.classes_:
        if actual != predicted and cm_df.loc[actual, predicted] > 0:
            confusions.append({
                "Actual": actual,
                "Predicted": predicted,
                "Count": cm_df.loc[actual, predicted]
            })

confusions_df = pd.DataFrame(confusions)

confusions_df = confusions_df.sort_values(
    "Count",
    ascending=False
)

display(confusions_df.head(20))
# Out:
#                    Actual              Predicted  Count
# 40             V-Neck Top            Flowy Dress      4
# 25         Layered Outfit             Peplum Top      4
# 19           Fitted Dress             Wrap Dress      3
# 27        Longline Jacket     Empire-Waist Dress      3
# 32  Straight-Leg Trousers     Empire-Waist Dress      3
# 31          Pleated Skirt         Layered Outfit      3
# 29             Peplum Top         Layered Outfit      3
# 22            Flowy Dress      Wide-Leg Trousers      2
# 1            A-Line Dress            Dark Bottom      2
# 5            A-Line Skirt      Wide-Leg Trousers      2
# 10          Belted Outfit             Wrap Dress      2
# 11          Boat-Neck Top           A-Line Dress      2
# 8            Belted Dress          Pleated Skirt      2
# 6            Belted Dress         Layered Outfit      2
# 34         Structured Top           A-Line Dress      2
# 38          V-Neck Outfit  Straight-Leg Trousers      2
# ...

# %%
cm_df = pd.DataFrame(
    cm,
    index=model.classes_,
    columns=model.classes_
)

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, f1_score

dummy = DummyClassifier(
    strategy="most_frequent",
    random_state=42
)

dummy.fit(X_train, y_train)

dummy_pred = dummy.predict(X_test)

dummy_accuracy = accuracy_score(y_test, dummy_pred)
dummy_macro_f1 = f1_score(
    y_test,
    dummy_pred,
    average="macro",
    zero_division=0
)

print("Baseline Accuracy:", dummy_accuracy)
print("Baseline Macro F1:", dummy_macro_f1)

print("\nRandom Forest Accuracy:", accuracy_score(y_test, y_pred))
print(
    "Random Forest Macro F1:",
    f1_score(y_test, y_pred, average="macro", zero_division=0)
)
# Out:
# Baseline Accuracy: 0.07
# Baseline Macro F1: 0.006542056074766355
#
# Random Forest Accuracy: 0.22
# Random Forest Macro F1: 0.19723090634855342

# %%
original_features = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

grouped_importance = {}

for feature in original_features:

    if feature in X_encoded.columns:
        grouped_importance[feature] = feature_importance.loc[
            feature_importance["Feature"] == feature,
            "Importance"
        ].sum()

    else:
        matching_columns = [
            col for col in X_encoded.columns
            if col.startswith(feature + "_")
        ]

        grouped_importance[feature] = feature_importance.loc[
            feature_importance["Feature"].isin(matching_columns),
            "Importance"
        ].sum()

grouped_importance_df = (
    pd.DataFrame(
        list(grouped_importance.items()),
        columns=["Feature", "Total_Importance"]
    )
    .sort_values(
        "Total_Importance",
        ascending=False
    )
)

display(grouped_importance_df)
# Out:
#             Feature  Total_Importance
# 0        Body_Shape          0.218459
# 7    Garment_Colour          0.100976
# 6      Garment_Type          0.084101
# 11           Fabric          0.077676
# 10          Pattern          0.070798
# 9          Neckline          0.068769
# 12         Occasion          0.064052
# 4   Hip_Waist_Ratio          0.062466
# 3            Hip_cm          0.055790
# 8            Sleeve          0.054055
# 2          Waist_cm          0.051782
# 1       Shoulder_cm          0.047945
# 5    Colour_Palette          0.043130

# %%
grouped_importance_df.sort_values(
    "Total_Importance"
).plot(
    x="Feature",
    y="Total_Importance",
    kind="barh",
    figsize=(10, 7),
    legend=False,
    title="Feature Importance by Original Feature"
)

plt.xlabel("Total Importance")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score
import pandas as pd

models = {
    "Random Forest": RandomForestClassifier(
        n_estimators=300,
        random_state=42
    ),

    "Extra Trees": ExtraTreesClassifier(
        n_estimators=300,
        random_state=42
    ),

    "Logistic Regression": LogisticRegression(
        max_iter=2000,
        random_state=42
    )
}

results = []

for name, model_test in models.items():

    model_test.fit(X_train, y_train)

    predictions = model_test.predict(X_test)

    accuracy = accuracy_score(y_test, predictions)

    macro_f1 = f1_score(
        y_test,
        predictions,
        average="macro",
        zero_division=0
    )

    weighted_f1 = f1_score(
        y_test,
        predictions,
        average="weighted",
        zero_division=0
    )

    results.append({
        "Model": name,
        "Accuracy": accuracy,
        "Macro F1": macro_f1,
        "Weighted F1": weighted_f1
    })

results_df = pd.DataFrame(results)

display(results_df.sort_values(
    "Macro F1",
    ascending=False
))
# Out:
# c:\Users\Krupa P\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 2000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=2000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                  Model  Accuracy  Macro F1  Weighted F1
# 0        Random Forest      0.27  0.240104     0.248305
# 1          Extra Trees      0.25  0.227100     0.236201
# 2  Logistic Regression      0.21  0.197732     0.198469

# %%
from sklearn.dummy import DummyClassifier

dummy = DummyClassifier(
    strategy="most_frequent",
    random_state=42
)

dummy.fit(X_train, y_train)

dummy_pred = dummy.predict(X_test)

print(
    "Majority Baseline Accuracy:",
    accuracy_score(y_test, dummy_pred)
)

print(
    "Majority Baseline Macro F1:",
    f1_score(
        y_test,
        dummy_pred,
        average="macro",
        zero_division=0
    )
)
# Out:
# Majority Baseline Accuracy: 0.07
# Majority Baseline Macro F1: 0.006542056074766355

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score
import pandas as pd

models = {
    "Random Forest": RandomForestClassifier(
        n_estimators=300,
        random_state=42
    ),

    "Extra Trees": ExtraTreesClassifier(
        n_estimators=300,
        random_state=42
    ),

    "Logistic Regression": LogisticRegression(
        max_iter=2000,
        random_state=42
    )
}

results = []

for name, model_test in models.items():

    model_test.fit(X_train, y_train)

    predictions = model_test.predict(X_test)

    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test, predictions),
        "Macro F1": f1_score(
            y_test,
            predictions,
            average="macro",
            zero_division=0
        ),
        "Weighted F1": f1_score(
            y_test,
            predictions,
            average="weighted",
            zero_division=0
        )
    })

results_df = pd.DataFrame(results)

display(results_df)
# Out:
# c:\Users\Krupa P\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 2000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=2000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                  Model  Accuracy  Macro F1  Weighted F1
# 0        Random Forest      0.27  0.240104     0.248305
# 1          Extra Trees      0.25  0.227100     0.236201
# 2  Logistic Regression      0.21  0.197732     0.198469

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf_model = RandomForestClassifier(
    n_estimators=300,
    random_state=42
)

rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

# %%
import numpy as np

probabilities = rf_model.predict_proba(X_test)

classes = rf_model.classes_

top3_indices = np.argsort(
    probabilities,
    axis=1
)[:, -3:][:, ::-1]

top3_predictions = classes[top3_indices]

top1_accuracy = np.mean(
    y_test.values == top3_predictions[:, 0]
)

top3_accuracy = np.mean([
    actual in predictions
    for actual, predictions in zip(
        y_test.values,
        top3_predictions
    )
])

print(f"Top-1 Accuracy: {top1_accuracy:.2%}")
print(f"Top-3 Accuracy: {top3_accuracy:.2%}")
# Out:
# Top-1 Accuracy: 27.00%
# Top-3 Accuracy: 73.00%

# %%
top3_results = pd.DataFrame({
    "Actual": y_test.values,
    "Prediction_1": top3_predictions[:, 0],
    "Prediction_2": top3_predictions[:, 1],
    "Prediction_3": top3_predictions[:, 2]
})

display(top3_results.head(20))
# Out:
#                    Actual           Prediction_1           Prediction_2  \
# 0      Empire-Waist Dress  Straight-Leg Trousers          V-Neck Outfit
# 1            Belted Dress          Pleated Skirt         Layered Outfit
# 2              Peplum Top           Belted Dress          Pleated Skirt
# 3              V-Neck Top            Flowy Dress             V-Neck Top
# 4           Pleated Skirt         Layered Outfit             Peplum Top
# 5           Pleated Skirt         Layered Outfit          Pleated Skirt
# 6              Peplum Top         Layered Outfit           Belted Dress
# 7           V-Neck Outfit          V-Neck Outfit        Longline Jacket
# 8   Straight-Leg Trousers     Empire-Waist Dress  Straight-Leg Trousers
# 9             Dark Bottom          Boat-Neck Top            Dark Bottom
# 10            Dark Bottom            Dark Bottom         Structured Top
# 11          Pleated Skirt         Layered Outfit          Pleated Skirt
# ...

# %%
from sklearn.model_selection import StratifiedKFold, cross_validate
from sklearn.ensemble import RandomForestClassifier

rf_cv = RandomForestClassifier(
    n_estimators=300,
    random_state=42
)

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

cv_results = cross_validate(
    rf_cv,
    X_encoded,
    y,
    cv=cv,
    scoring={
        "accuracy": "accuracy",
        "macro_f1": "f1_macro",
        "weighted_f1": "f1_weighted"
    }
)

print("5-Fold Cross-Validation Results")
print("--------------------------------")

print(
    f"Accuracy: "
    f"{cv_results['test_accuracy'].mean():.3f} "
    f"+/- "
    f"{cv_results['test_accuracy'].std():.3f}"
)

print(
    f"Macro F1: "
    f"{cv_results['test_macro_f1'].mean():.3f} "
    f"+/- "
    f"{cv_results['test_macro_f1'].std():.3f}"
)

print(
    f"Weighted F1: "
    f"{cv_results['test_weighted_f1'].mean():.3f} "
    f"+/- "
    f"{cv_results['test_weighted_f1'].std():.3f}"
)
# Out:
# 5-Fold Cross-Validation Results
# --------------------------------
# Accuracy: 0.254 +/- 0.019
# Macro F1: 0.235 +/- 0.023
# Weighted F1: 0.239 +/- 0.016

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd

# Train final candidate Random Forest
rf_model = RandomForestClassifier(
    n_estimators=300,
    random_state=42
)

rf_model.fit(X_train, y_train)

# Prediction probabilities
probabilities = rf_model.predict_proba(X_test)

classes = rf_model.classes_

# Get top 3 predictions for every test row
top3_indices = np.argsort(
    probabilities,
    axis=1
)[:, -3:][:, ::-1]

top3_predictions = classes[top3_indices]

# Top-1 accuracy
top1_accuracy = np.mean(
    y_test.values == top3_predictions[:, 0]
)

# Top-3 accuracy
top3_accuracy = np.mean([
    actual in predictions
    for actual, predictions in zip(
        y_test.values,
        top3_predictions
    )
])

print(f"Top-1 Accuracy: {top1_accuracy:.2%}")
print(f"Top-3 Accuracy: {top3_accuracy:.2%}")
# Out:
# Top-1 Accuracy: 27.00%
# Top-3 Accuracy: 73.00%

# %%
top3_results = pd.DataFrame({
    "Actual": y_test.values,
    "Recommendation_1": top3_predictions[:, 0],
    "Recommendation_2": top3_predictions[:, 1],
    "Recommendation_3": top3_predictions[:, 2]
})

display(top3_results.head(20))
# Out:
#                    Actual       Recommendation_1       Recommendation_2  \
# 0      Empire-Waist Dress  Straight-Leg Trousers          V-Neck Outfit
# 1            Belted Dress          Pleated Skirt         Layered Outfit
# 2              Peplum Top           Belted Dress          Pleated Skirt
# 3              V-Neck Top            Flowy Dress             V-Neck Top
# 4           Pleated Skirt         Layered Outfit             Peplum Top
# 5           Pleated Skirt         Layered Outfit          Pleated Skirt
# 6              Peplum Top         Layered Outfit           Belted Dress
# 7           V-Neck Outfit          V-Neck Outfit        Longline Jacket
# 8   Straight-Leg Trousers     Empire-Waist Dress  Straight-Leg Trousers
# 9             Dark Bottom          Boat-Neck Top            Dark Bottom
# 10            Dark Bottom            Dark Bottom         Structured Top
# 11          Pleated Skirt         Layered Outfit          Pleated Skirt
# ...

# %%
from sklearn.model_selection import StratifiedKFold, cross_validate

cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

rf_cv = RandomForestClassifier(
    n_estimators=300,
    random_state=42
)

cv_results = cross_validate(
    rf_cv,
    X_encoded,
    y,
    cv=cv,
    scoring={
        "accuracy": "accuracy",
        "macro_f1": "f1_macro",
        "weighted_f1": "f1_weighted"
    }
)

print("5-Fold Cross-Validation")
print("-----------------------")

print(
    f"Accuracy: "
    f"{cv_results['test_accuracy'].mean():.3f} "
    f"+/- "
    f"{cv_results['test_accuracy'].std():.3f}"
)

print(
    f"Macro F1: "
    f"{cv_results['test_macro_f1'].mean():.3f} "
    f"+/- "
    f"{cv_results['test_macro_f1'].std():.3f}"
)

print(
    f"Weighted F1: "
    f"{cv_results['test_weighted_f1'].mean():.3f} "
    f"+/- "
    f"{cv_results['test_weighted_f1'].std():.3f}"
)
# Out:
# 5-Fold Cross-Validation
# -----------------------
# Accuracy: 0.254 +/- 0.019
# Macro F1: 0.235 +/- 0.023
# Weighted F1: 0.239 +/- 0.016

# %%
probabilities = rf_model.predict_proba(X_test)

classes = rf_model.classes_

top3_indices = np.argsort(
    probabilities,
    axis=1
)[:, -3:][:, ::-1]

top3_predictions = classes[top3_indices]

top1_accuracy = np.mean(
    y_test.values == top3_predictions[:, 0]
)

top3_accuracy = np.mean([
    actual in predictions
    for actual, predictions in zip(
        y_test.values,
        top3_predictions
    )
])

print(f"Top-1 Accuracy: {top1_accuracy:.2%}")
print(f"Top-3 Accuracy: {top3_accuracy:.2%}")
# Out:
# Top-1 Accuracy: 27.00%
# Top-3 Accuracy: 73.00%

# %%
features = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

X = df[features].copy()
y = df["Recommendation"].copy()

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

numeric_features = [
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio"
]

categorical_features = [
    "Body_Shape",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            "passthrough",
            numeric_features
        ),
        (
            "cat",
            OneHotEncoder(
                handle_unknown="ignore"
            ),
            categorical_features
        )
    ]
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            "passthrough",
            numeric_features
        ),
        (
            "cat",
            OneHotEncoder(
                handle_unknown="ignore"
            ),
            categorical_features
        )
    ]
)

# %%
final_model.fit(X, y)

print("Final StyleMate model trained successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 final_model.fit(X, y)
#       2
#       3 print("Final StyleMate model trained successfully.")
#
# NameError: name 'final_model' is not defined

# %%
features = [
    "Body_Shape",
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

X = df[features].copy()
y = df["Recommendation"].copy()

# %%
numeric_features = [
    "Shoulder_cm",
    "Waist_cm",
    "Hip_cm",
    "Hip_Waist_Ratio"
]

categorical_features = [
    "Body_Shape",
    "Colour_Palette",
    "Garment_Type",
    "Garment_Colour",
    "Sleeve",
    "Neckline",
    "Pattern",
    "Fabric",
    "Occasion"
]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

preprocessor = ColumnTransformer(
    transformers=[
        (
            "num",
            "passthrough",
            numeric_features
        ),
        (
            "cat",
            OneHotEncoder(handle_unknown="ignore"),
            categorical_features
        )
    ]
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

final_model = Pipeline(
    steps=[
        (
            "preprocessor",
            preprocessor
        ),
        (
            "classifier",
            RandomForestClassifier(
                n_estimators=300,
                random_state=42
            )
        )
    ]
)

print("final_model created successfully")
# Out:
# final_model created successfully

# %%
final_model.fit(X, y)

print("Final StyleMate model trained successfully!")
# Out:
# Final StyleMate model trained successfully!

# %%
sample_input = pd.DataFrame([{
    "Body_Shape": "Pear",
    "Shoulder_cm": 36,
    "Waist_cm": 30,
    "Hip_cm": 42,
    "Hip_Waist_Ratio": 42 / 30,
    "Colour_Palette": "Warm",
    "Garment_Type": "Dress",
    "Garment_Colour": "Blue",
    "Sleeve": "3/4",
    "Neckline": "V-Neck",
    "Pattern": "Floral",
    "Fabric": "Rayon",
    "Occasion": "Party"
}])

prediction = final_model.predict(sample_input)

print("Recommended Style:", prediction[0])
# Out:
# Recommended Style: A-Line Dress

# %%
import numpy as np

probabilities = final_model.predict_proba(sample_input)[0]
classes = final_model.classes_

top3_indices = np.argsort(probabilities)[-3:][::-1]

print("Top 3 Style Recommendations")
print("----------------------------")

for rank, index in enumerate(top3_indices, start=1):
    print(
        f"{rank}. {classes[index]} "
        f"({probabilities[index]:.2%})"
    )
# Out:
# Top 3 Style Recommendations
# ----------------------------
# 1. A-Line Dress (34.67%)
# 2. Dark Bottom (21.33%)
# 3. Structured Top (18.00%)

# %%
import joblib

joblib.dump(
    final_model,
    "stylemate_model.pkl"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
import numpy as np

probabilities = final_model.predict_proba(sample_input)[0]
classes = final_model.classes_

top3_indices = np.argsort(probabilities)[-3:][::-1]

print("Top 3 Style Recommendations")
print("----------------------------")

for rank, index in enumerate(top3_indices, start=1):
    print(
        f"{rank}. {classes[index]} "
        f"({probabilities[index]:.2%})"
    )
# Out:
# Top 3 Style Recommendations
# ----------------------------
# 1. A-Line Dress (34.67%)
# 2. Dark Bottom (21.33%)
# 3. Structured Top (18.00%)

# %%
import joblib

joblib.dump(
    final_model,
    "stylemate_model.pkl"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
joblib.dump(
    {
        "features": features,
        "numeric_features": numeric_features,
        "categorical_features": categorical_features
    },
    "stylemate_config.pkl"
)

print("Configuration saved successfully!")
# Out:
# Configuration saved successfully!

# %%
import joblib

joblib.dump(
    final_model,
    "stylemate_model.pkl"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
import os

print(os.getcwd())
print(os.path.exists("stylemate_model.pkl"))
# Out:
# c:\Users\Krupa P\OneDrive\Desktop\stylemate\dataset
# True

# %%
import os

print("Current folder:")
print(os.getcwd())

print("\nModel exists:")
print(os.path.exists("stylemate_model.pkl"))
# Out:
# Current folder:
# c:\Users\Krupa P\OneDrive\Desktop\stylemate\dataset
#
# Model exists:
# True

# %%
import os

print(os.path.exists("stylemate_model.pkl"))
# Out:
# True

# %%
import sys

print("Python version:")
print(sys.version)

print("\nPython executable:")
print(sys.executable)
# Out:
# Python version:
# 3.12.0 (tags/v3.12.0:0fb18b0, Oct  2 2023, 13:03:39) [MSC v.1935 64 bit (AMD64)]
#
# Python executable:
# c:\Users\Krupa P\AppData\Local\Programs\Python\Python312\python.exe

# %%
# !pip install mediapipe opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/20.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/20.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/20.1 MB ? eta -:--:--
#    - -------------------------------------- 0.8/20.1 MB 1.9 MB/s eta 0:00:11
#    -- ------------------------------------- 1.0/20.1 MB 1.4 MB/s eta 0:00:14
#    -- ------------------------------------- 1.3/20.1 MB 1.4 MB/s eta 0:00:14
#    --- ------------------------------------ 1.8/20.1 MB 1.5 MB/s eta 0:00:12
#    ---- ----------------------------------- 2.1/20.1 MB 1.5 MB/s eta 0:00:12
#    ---- ----------------------------------- 2.4/20.1 MB 1.6 MB/s eta 0:00:12
#    ----- ---------------------------------- 2.6/20.1 MB 1.6 MB/s eta 0:00:12
#    ----- ---------------------------------- 2.9/20.1 MB 1.5 MB/s eta 0:00:12
#    ----- ---------------------------------- 2.9/20.1 MB 1.5 MB/s eta 0:00:12
# ...

# %%
import cv2
import mediapipe as mp

print("OpenCV version:", cv2.__version__)
print("MediaPipe imported successfully!")
# Out:
# OpenCV version: 5.0.0
# MediaPipe imported successfully!

# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt

image_path = "images/test_body.jpg"

image = cv2.imread(image_path)

if image is None:
    print("❌ Image not found. Check the path.")
else:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    mp_pose = mp.solutions.pose
    mp_drawing = mp.solutions.drawing_utils

    with mp_pose.Pose(
        static_image_mode=True,
        model_complexity=2,
        min_detection_confidence=0.5
    ) as pose:

        results = pose.process(image_rgb)

        if results.pose_landmarks:
            print("✅ Body detected successfully!")

            annotated_image = image_rgb.copy()

            mp_drawing.draw_landmarks(
                annotated_image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS
            )

            plt.figure(figsize=(8, 10))
            plt.imshow(annotated_image)
            plt.axis("off")
            plt.title("StyleMate - Body Landmark Detection")
            plt.show()

        else:
            print("❌ No body detected.")
# Out:
# ❌ Image not found. Check the path.

# %%
from ultralytics import YOLO

print("YOLO imported successfully!")
# Out:
# Creating new Ultralytics Settings v0.0.8 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Krupa P\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# YOLO imported successfully!

# %%
from ultralytics import YOLO

# %%
print("YOLO imported successfully!")
# Out:
# YOLO imported successfully!

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load the YOLO pose model
pose_model = YOLO("yolo11n-pose.pt")

# Read the image
image = cv2.imread("images/test_body.jpg")

if image is None:
    print("❌ Image not found. Check the image path.")
else:
    # Run pose detection
    results = pose_model(image)

    # Draw detected body landmarks
    annotated_image = results[0].plot()

    # Display the result
    plt.figure(figsize=(8, 10))
    plt.imshow(
        cv2.cvtColor(
            annotated_image,
            cv2.COLOR_BGR2RGB
        )
    )
    plt.axis("off")
    plt.title("StyleMate - Body Landmark Detection")
    plt.show()
# Out:
# ❌ Image not found. Check the image path.

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\Krupa P\OneDrive\Desktop\stylemate\dataset

# %%
from pathlib import Path

for item in Path.cwd().iterdir():
    print(item.name)
# Out:
# dataset_analysis.ipynb
# personalized_fashion_dataset_500 (1).csv
# StyleMate_cleaned.csv
# stylemate_config.pkl
# stylemate_model.pkl
# StyleMate_with_height.csv
# yolo11n-pose.pt

# %%
from pathlib import Path
import os

PROJECT_DIR = Path(
    r"C:\Users\Krupa P\OneDrive\Desktop\stylemate"
)

os.chdir(PROJECT_DIR)

print("Current working directory:")
print(Path.cwd())
# Out:
# Current working directory:
# C:\Users\Krupa P\OneDrive\Desktop\stylemate

# %%
from pathlib import Path

images_folder = PROJECT_DIR / "images"

images_folder.mkdir(
    exist_ok=True
)

print("Images folder:")
print(images_folder)
# Out:
# Images folder:
# C:\Users\Krupa P\OneDrive\Desktop\stylemate\images
